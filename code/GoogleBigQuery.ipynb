# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#References" data-toc-modified-id="References-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>References</a></span></li><li><span><a href="#Reading-data-from-GDELT-GKG" data-toc-modified-id="Reading-data-from-GDELT-GKG-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reading data from GDELT GKG</a></span><ul class="toc-item"><li><span><a href="#Class-objects" data-toc-modified-id="Class-objects-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Class objects</a></span></li><li><span><a href="#Search-string" data-toc-modified-id="Search-string-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Search string</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#References" data-toc-modified-id="References-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>References</a></span></li></ul></li><li><span><a href="#Establish-programming-components" data-toc-modified-id="Establish-programming-components-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Establish programming components</a></span><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Establish-parameters" data-toc-modified-id="Establish-parameters-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Establish parameters</a></span></li><li><span><a href="#GDELT-fields-available-from-Google-BigQuery" data-toc-modified-id="GDELT-fields-available-from-Google-BigQuery-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>GDELT fields available from Google BigQuery</a></span></li><li><span><a href="#Establish-classes" data-toc-modified-id="Establish-classes-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Establish classes</a></span></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Define functions</a></span></li></ul></li><li><span><a href="#Collect-metrics-data" data-toc-modified-id="Collect-metrics-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Collect metrics data</a></span><ul class="toc-item"><li><span><a href="#Test-the-objects" data-toc-modified-id="Test-the-objects-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Test the objects</a></span></li><li><span><a href="#Query-BigQuery-for-press-coverage" data-toc-modified-id="Query-BigQuery-for-press-coverage-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Query BigQuery for press coverage</a></span><ul class="toc-item"><li><span><a href="#Read-in-the-poll-data" data-toc-modified-id="Read-in-the-poll-data-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Read in the poll data</a></span></li><li><span><a href="#Establish-search-criteria" data-toc-modified-id="Establish-search-criteria-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Establish search criteria</a></span></li><li><span><a href="#Search-press-coverage-for-each-candidate" data-toc-modified-id="Search-press-coverage-for-each-candidate-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Search press coverage for each candidate</a></span></li></ul></li></ul></li><li><span><a href="#Store-in-a-DataFrame" data-toc-modified-id="Store-in-a-DataFrame-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Store in a DataFrame</a></span><ul class="toc-item"><li><span><a href="#Concatenate-DataFrames" data-toc-modified-id="Concatenate-DataFrames-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Concatenate DataFrames</a></span></li></ul></li></ul></div>

# %% [markdown]
# # References
#
# # Reading data from GDELT GKG
#
# This module uses Google's BigQuery application programming interface (API) to pull press coverage data from the Global Data on Events Language and Tone (GDELT) Global Knowledge Graph Version 2 (GKG V2) database.  Specifically, it pulls specific press coverage metrics of individual subjects including article and word counts and the GDELT CKG values for tone, positive and negative scores, polarity and activity reference density and self reference density. More information on these scores can be found in the GDELT [documentation](http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_Codebook-V2.1.pdf)
#
# It stores these data in a DataFrame and outputs them to a comma separated value (CSV) file.
#
#
# ## Class objects
#
# To retrieve the coverage metrics, this code employs a class object designed to interact the Google BigQuery Python [API](https://cloud.google.com/bigquery/docs/reference/libraries) and to query the GDELT GKG database.  The class object is GKGPersonPressMetrics and it is developed to retrieve and store in memory press coverage metrics for an individual.  It is built using Google tools including the aforementioned API and the BigQuery public datasets which include GDELT [tables](https://www.gdeltproject.org/data.html#googlebigquery).
#
#    * GKGPersonPressMetrics attributes:
#        * table - the GDELT GKG V2 table at Google BigQuery
#        * subject - the name of the individual for whom metrics will be retrieved
#        * start_time - the beginning date/time for the search window
#        * end_time - the ending date/time for the search window
#        * fields - the GKG V2 fields to retrieve with the query
#        * query - the SQL query statement
#        * limit - the maximum number of results to return
#        * metrics_ - a dictionary of the returned metrics
#
#
#    * GKGPersonPressMetrics methods:
#        * build_sql() - build the SQL statement used in the press metric search
#        * collect_metrics() - execute the search and return a dictionary of metrics
#
# ## Search string
#
# The GKGPersonPressMetrics object uses a base search string which consists of the following criteria:
#
#    * Select the specified columns from the GKG V2 table
#    * Where the GKG V2 Persons field is searched for names matching the subject
#    * And the dates fall within the specified interval
#    * Limit the returned output to a maximum
#
#
#
# ## Data
#
# The data delineated below are the returned and calculated press metrics.
#
# |Column        |Description    |
# |-----------------|--------------------|
# |Subject  | name of the individual searched in the Persons field|
# |start_time| a datetime object of the search window's start|
# |end_time|  a datetime object of the search window's end|
# |press_count  | the count of articles including the subject's name and within the time interval|
# |word_count| the sum of the word counts of returned articles|
# |tone_avg| the average of GDELT's tone measure for the returned articles|
# |pos_score_avg  |the average of GDELT's positive score for the returned articles|
# |neg_score_avg| the average of GDELT's negative score for the returned articles|
# |polarity_avg| the average of GDELT's polarity measure for the returned articles|
# |act_ref_den_avg  | the average of GDELT's active reference density measure for the returned articles|
# |self_ref_den_avg|  the average of GDELT's self reference density measure for the returned articles|
#
#
# ## References
#
# - https://cloud.google.com/bigquery/docs/reference/libraries#client-libraries-install-python
# - https://pandas-gbq.readthedocs.io/en/latest/index.html
# - http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_Codebook-V2.1.pdf
# - https://blog.gdeltproject.org/introducing-the-global-content-analysis-measures-gcam/
# - https://ivmooc.cns.iu.edu/docs/gdelt-results.pdf
# - http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_CategoryList.xlsx
# - https://stackoverflow.com/questions/51967429/understanding-themes-in-google-bigquery-gdelt-gkg-2-0

# %% [markdown]
# # Establish programming components

# %% [markdown]
# ## Import libraries

# %%
# !pip install --upgrade google-cloud-bigquery
#!pip install versioneer
#!pip install git+https://github.com/pydata/pandas-gbq.git - followed conda install instructions

#import versioneer
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sqlalchemy import create_engine
import psycopg2
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas_gbq
import time
from time import sleep

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Establish parameters

# %% [markdown]
# ## GDELT fields available from Google BigQuery

# %%
'''   
GKGRECORDID	STRING	NULLABLE	
DATE	INTEGER	NULLABLE	
SourceCollectionIdentifier	INTEGER	NULLABLE	
SourceCommonName	STRING	NULLABLE	
DocumentIdentifier	STRING	NULLABLE	
Counts	STRING	NULLABLE	
V2Counts	STRING	NULLABLE	
Themes	STRING	NULLABLE	
V2Themes	STRING	NULLABLE	
Locations	STRING	NULLABLE	
V2Locations	STRING	NULLABLE	
Persons	STRING	NULLABLE	
V2Persons	STRING	NULLABLE	
Organizations	STRING	NULLABLE	
V2Organizations	STRING	NULLABLE	
V2Tone	STRING	NULLABLE	
Dates	STRING	NULLABLE	
GCAM	STRING	NULLABLE	.
SharingImage	STRING	NULLABLE	
RelatedImages	STRING	NULLABLE	.
SocialImageEmbeds	STRING	NULLABLE	
SocialVideoEmbeds	STRING	NULLABLE	
Quotations	STRING	NULLABLE	
AllNames	STRING	NULLABLE	
Amounts	STRING	NULLABLE	.
TranslationInfo	STRING	NULLABLE	
Extras
'''
# Out:
# '   \nGKGRECORDID\tSTRING\tNULLABLE\t\nDATE\tINTEGER\tNULLABLE\t\nSourceCollectionIdentifier\tINTEGER\tNULLABLE\t\nSourceCommonName\tSTRING\tNULLABLE\t\nDocumentIdentifier\tSTRING\tNULLABLE\t\nCounts\tSTRING\tNULLABLE\t\nV2Counts\tSTRING\tNULLABLE\t\nThemes\tSTRING\tNULLABLE\t\nV2Themes\tSTRING\tNULLABLE\t\nLocations\tSTRING\tNULLABLE\t\nV2Locations\tSTRING\tNULLABLE\t\nPersons\tSTRING\tNULLABLE\t\nV2Persons\tSTRING\tNULLABLE\t\nOrganizations\tSTRING\tNULLABLE\t\nV2Organizations\tSTRING\tNULLABLE\t\nV2Tone\tSTRING\tNULLABLE\t\nDates\tSTRING\tNULLABLE\t\nGCAM\tSTRING\tNULLABLE\t.\nSharingImage\tSTRING\tNULLABLE\t\nRelatedImages\tSTRING\tNULLABLE\t.\nSocialImageEmbeds\tSTRING\tNULLABLE\t\nSocialVideoEmbeds\tSTRING\tNULLABLE\t\nQuotations\tSTRING\tNULLABLE\t\nAllNames\tSTRING\tNULLABLE\t\nAmounts\tSTRING\tNULLABLE\t.\nTranslationInfo\tSTRING\tNULLABLE\t\nExtras\n'

# %%
# Environment variables for the Google BigQuery API
bq_cred = '/Users/stephengodfrey/Documents/SteveSchool/dsi/GoogleCloud/BigQuery/CampFireAnalysis-c65ccd07c4d9.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = bq_cred

credentials = service_account.Credentials.from_service_account_file(bq_cred,)

dataset_id = 'campfireanalysis:rep_primary_press_coverage_2016'
table_id = 't1'


# Instantiate the object
client = bigquery.Client()

# Configure BigQuery
job_config = bigquery.QueryJobConfig()
# Set the destination table
table_ref = client.dataset(dataset_id).table(table_id)
job_config.destination = table_ref
job_config.allow_large_results = True
job_config.write_disposition = 'WRITE_APPEND'


# conn_str = 'postgres://postgres:' + str(password) + '@54.200.180.8:5432'
conn_str = 'postgres://postgres:A%A$TSHBSA@54.200.180.8:5432'

# Database engine
engine = create_engine(conn_str)

# %% [markdown]
# ## Establish classes

# %%
class GKGPersonPressMetrics:
    # Attributes of the data retrieval
    table = "`gdelt-bq.gdeltv2.gkg`"
    subject = ''
    start_time = '20150201000000'
    end_time = '20150202000000'
    fields = ['V2Tone']
    query = ''
    limit = 10
    metrics_ = {}
    
    # Initialization method
    def __init__(self, subject = '', start_time = None, end_time = None, fields = [], limit = 0):
        # update self variables
        if subject != '':
            self.subject = subject
        if start_time != None:
            self.start_time = start_time
        if end_time != None:
            self.end_time = end_time        
        if len(fields) != 0:
            self.fields = fields
        if limit != 0:
            self.limit = limit    
            
    # Build the SQL string
    def build_sql(self):
        
        # Construct a query given the attributes of the class       
        self.query = (
            "SELECT "+", ".join(self.fields)+" FROM `gdelt-bq.gdeltv2.gkg` "
            "WHERE Persons LIKE('%"+self.subject.lower()+"%') AND "
            "DATE > "+self.start_time+" AND DATE <"+self.end_time+
            " LIMIT "+str(self.limit)
        )
        return self.query
    
    # method to collect data from posts
    def collect_metrics(self):
        
        # Instantiate the object
        client = bigquery.Client()

        # Run the query
        query_job = client.query(self.query, location="US")
        
        
        # Check for errors
        if query_job.errors != None:
            if query_job.errors[0]['reason'] == 'invalidQuery':
                # Try to build the sql then run the query again
                self.build_sql()               
                query_job = client.query(self.query, location="US")
            if query_job.errors != None:
                raise ValueError('Error with query: ' + query_job.errors[0]['reason'])           
        
        m_d = {}
        # Look in the query to get metrics
        count = 0
        tone = 0
        pos_score = 0
        neg_score = 0
        polarity = 0
        act_ref_den = 0
        self_ref_den = 0
        word_count = 0
        
        # Examine each row returned from the query
        for row in query_job:
            count += 1
            # Get the tone metrics from the V2Tone column
            try:
                tone_metrics = row.get('V2Tone').split(',')
                tone += float(tone_metrics[0])
                pos_score += float(tone_metrics[1])
                neg_score += float(tone_metrics[2])
                polarity  += float(tone_metrics[3])
                act_ref_den += float(tone_metrics[4])
                self_ref_den += float(tone_metrics[5])
                word_count += int(tone_metrics[6])
            except:
                pass
            
        # Assign some dictionary values
        m_d['subject'] = self.subject
        m_d['start_time'] = datetime.strptime(self.start_time,'%Y%m%d%H%M%S')
        m_d['end_time'] = datetime.strptime(self.end_time,'%Y%m%d%H%M%S')        
        m_d['press_count'] = count
        m_d['word_count'] = word_count
        
        # Store the average tonal scores
        if count != 0:
            m_d['tone_avg'] = tone/count
            m_d['pos_score_avg'] = pos_score/count            
            m_d['neg_score_avg'] = neg_score/count  
            m_d['polarity_avg'] = polarity/count
            m_d['act_ref_den_avg'] = act_ref_den/count
            m_d['self_ref_den_avg'] = self_ref_den/count
        else:
            m_d['tone_avg'] = np.NAN
            m_d['pos_score_avg'] = np.NAN            
            m_d['neg_score_avg'] = np.NAN  
            m_d['polarity_avg'] = np.NAN
            m_d['act_ref_den_avg'] = np.NAN
            m_d['self_ref_den_avg'] = np.NAN
       
        self.metrics_ = m_d
        return m_d


class PressInventory:   
    # Table to search from
    search_table = ''
    # Dataset and table to write to
    dataset_id = ''
    table_id = ''   
    # List of subjects
    subjects = []
    # Tuple of start and end times
    search_times = ()
    # GDELT fields to retrieve
    fields=[]
    # Maximum number of articles to return
    limit = None
    
    # Initialization method
    def __init__(self, search_table = '', dataset_id = '', table_id = '',
                 subjects = [], search_times = [], fields = [], limit = None):
        
        # update class variables        
        if search_table != '':
            self.search_table = search_table
        if dataset_id != '':
            self.dataset_id = dataset_id
        if table_id != '':
            self.table_id = table_id
        if len(subjects) != 0:
            self.subjects = subjects
        if len(search_times) != 0:
            self.search_times = search_times     
        if len(fields) != 0:
            self.fields = fields
        if limit != None:
            self.limit = limit 
                 
    # Build the SQL string
    def build_sql(self):
        # Construct the select statement
        sel_stm = "SELECT DISTINCT " + ", ".join(self.fields) + " FROM " + self.search_table + " "
        # Construct the subject statement
        sub_stm = ["Persons LIKE('%" + subject.lower() +"%') OR" for subject in self.subjects[:-1]]
        sub_stm = "WHERE " + " ".join(sub_stm) + " Persons LIKE('%" + self.subjects[-1].lower() +"%')"
        # Construct the time statement
        time_stm = " AND DATE > " + self.search_times[0] + " AND DATE < " + self.search_times[1]
        # Construct the limit statement
        if self.limit == None:
            limit_stm = ''
        else:
            limit_stm = " LIMIT "+str(self.limit)
            
        # Construct a query given the attributes of the class       
        self.query = sel_stm + sub_stm + time_stm + limit_stm
        return self.query
    
    
    def collect_coverage(self):      
        
        # Instantiate the object
        client = bigquery.Client()

        # Configure BigQuery
        job_config = bigquery.QueryJobConfig()
        # Set the destination table
        table_ref = client.dataset(self.dataset_id).table(self.table_id)
        job_config.destination = table_ref
        # Set job parameters
        job_config.allow_large_results = True
        job_config.write_disposition = 'WRITE_APPEND'

        # Run the query
        query_job = client.query(self.query, 
                                 location="US",
                                 job_config=job_config)
                
        # Check for errors
        if query_job.errors != None:
            if query_job.errors[0]['reason'] == 'invalidQuery':
                # Try to build the sql then run the query again
                self.build_sql()               
                # Run the query
                query_job = client.query(self.query, 
                                         location="US",
                                         job_config=job_config)
            if query_job.errors != None:
                print(query_job.errors)
                raise ValueError('Error with query: ' + query_job.errors[0]['reason'])           
        
        # Wait for job to finish
        query_job.result()
        print('Query results loaded to table {}'.format(table_ref.path))
                
        return

# %%
search_table = "`gdelt-bq.gdeltv2.gkg`"
#dataset_id = 'campfireanalysis:rep_primary_press_coverage_2016'
dataset_id = 'rep_primary_press_coverage_2016'
table_id = 't1'


subjects = ['Donald Trump', 'John Kasich', 'Ted Cruz', 'Marco Rubio', 'Ben Carson', 'Jeb Bush', 
            'Chris Christie', 'Carly Fiorina', 'Rick Santorum', 'Rand Paul', 'Mike Huckabee']
    # Tuple of start and end times
search_times = ('20150503000000','20160503000000')
# GDELT fields to retrieve
fields=['GKGRECORDID','Date','Allnames','Persons','V2Tone','V2Themes']

press = PressInventory(search_table=search_table, dataset_id=dataset_id, table_id=table_id,
                       subjects=subjects, search_times=search_times,fields=fields, limit=None)

print(press.build_sql())

press.collect_coverage()
# Out:
# SELECT DISTINCT GKGRECORDID, Date, Allnames, Persons, V2Tone, V2Themes FROM `gdelt-bq.gdeltv2.gkg` WHERE Persons LIKE('%donald trump%') OR Persons LIKE('%john kasich%') OR Persons LIKE('%ted cruz%') OR Persons LIKE('%marco rubio%') OR Persons LIKE('%ben carson%') OR Persons LIKE('%jeb bush%') OR Persons LIKE('%chris christie%') OR Persons LIKE('%carly fiorina%') OR Persons LIKE('%rick santorum%') OR Persons LIKE('%rand paul%') OR Persons LIKE('%mike huckabee%') AND DATE > 20150503000000 AND DATE < 20160503000000
# Query results loaded to table /projects/campfireanalysis/datasets/rep_primary_press_coverage_2016/tables/t1

# %%
test = GKGPersonPressMetrics(subject='John Kasich')
print(test.build_sql())
# Out:
# SELECT V2Tone FROM `gdelt-bq.gdeltv2.gkg` WHERE Persons LIKE('%john kasich%') AND DATE > 20150201000000 AND DATE <20150202000000 LIMIT 10

# %% [markdown]
# ## Define functions

# %%
# Retrieve press coverage metrics for a particular candidate
def survey_coverage_by_subject_by_day(subject = '', start_time = '', end_time = '',
                           fields = ['DATE', 'AllNames', 'Persons', 'V2Tone'],
                           limit = 1000):
    
    # Convert dates to datetime objects
    # Establish four times - start and end of coverage period
    #  start and end of each daily interval
    dt_start = datetime.strptime(start_time,'%Y%m%d%H%M%S')
    dt_end = datetime.strptime(end_time,'%Y%m%d%H%M%S')
    dt_interval_start = dt_start
    dt_interval_end =  dt_interval_start + timedelta(days=1)
    
    # Set up a list to hold dictionaries resulting from the search
    i_metrics = []
    
    while dt_interval_end <= dt_end:
        # convert daily intervals to strings
        time1 = dt_interval_start.strftime('%Y%m%d%H%M%S')
        time2 = dt_interval_end.strftime('%Y%m%d%H%M%S')
    
        # Tell the user what's happening
        print(f'Retrieving coverage metrics on {subject} for interval {time1} to {time2}')

        # Instantiate metrics class
        metric = GKGPersonPressMetrics(subject = subject, 
                                       start_time = time1, 
                                       end_time = time2,
                                       fields = fields,
                                       limit = limit)
        
        # Collect metrics for this interval
        this_metric = metric.collect_metrics()
        
        # Append these metrics to i_metrics
        i_metrics.append(this_metric)
        
        # Advance the day by one day
        dt_interval_start = dt_interval_end
        dt_interval_end = dt_interval_end + timedelta(days=1)
        
        # Pause before proceeding 
        time.sleep(1)
               
        # Create a DataZFrame and re-order columns
        df = pd.DataFrame(i_metrics)
        df = df[['subject','start_time','end_time','press_count','word_count',
                 'tone_avg','pos_score_avg','neg_score_avg','polarity_avg',
                 'act_ref_den_avg','self_ref_den_avg']]

    return df


# Create a list of tuples with start and end date
def create_search_dates(df = None):
    # Set the first date to the first date in the index - 7 days + 1 minute
    first_date = datetime.strptime(df.index[0],'%Y-%m-%d')-timedelta(days=7)+timedelta(minutes=1)
    first_date = first_date.strftime('%Y-%m-%d%H%M%S')
    # Create a list of tuples with start and end dates for each interval
    search_dates = [(i.replace('-','')+'000100',j.replace('-','')+'235900') \
                    for i,j in zip(df.index[:-1],df.index[1:])]
    # Add the first date into the list
    search_dates.insert(0,(first_date,df.index[0].replace('-','')+'235900'))
    return search_dates


def create_data_parameters(df = None, subjects = {}):
     
    # Set the first date to the first date in the index - 7 days + 1 minute
    start_time = datetime.strptime(df.index[0],'%Y-%m-%d')-timedelta(days=7)+timedelta(minutes=1)
    start_time = start_time.strftime('%Y%m%d%H%M%S')
   
    # For each candidate and each date in the index determine the performance in the next poll
    data_params = []
    for subject in subjects.keys():
        # Get the column for this subject
        col_i = df.columns.get_loc(subject)
        
        for i in range(len(df.index)-1):
            poll_result = {}
            next_poll_res = df.iloc[i+1,col_i] - df.iloc[i,col_i]
            if not pd.isnull(next_poll_res):
                poll_result['candidate'] = subjects[subject]
                poll_result['poll_res'] = df.iloc[i,col_i]
                if i  > 1:
                    start_time = df.index[i-1].replace('-','')+'000100'
                poll_result['start_time'] = start_time
                poll_result['end_time'] = df.index[i].replace('-','')+'235900'
                poll_result['next_poll_delta'] = next_poll_res
                data_params.append(poll_result)
    return data_params

# %%
subject_mapping  = {'Trump':'Donald Trump', 'Kasich': 'John Kasich', 'Cruz':'Ted Cruz', 
                    'Rubio':'Marco Rubio', 'Carson':'Ben Carson', 'Bush':'Jeb Bush', 
                    'Christie':'Chris Christie', 'Fiorina':'Carly Fiorina', 'Santorum':'Rick Santorum', 
                    'Paul':'Rand Paul', 'Huckabee':'Mike Huckabee'}


test_d = create_data_parameters(df = df_polls_2016, subjects = subject_mapping)

# %%
print(len(test_d))
test_d
# Out:
# 3853
# [{'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150315000100',
#   'end_time': '20150319235900',
#   'next_poll_delta': 0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150319000100',
#   'end_time': '20150320235900',
#   'next_poll_delta': 0.02},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150320000100',
#   'end_time': '20150321235900',
#   'next_poll_delta': 0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150321000100',
#   'end_time': '20150322235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.06,
#   'start_time': '20150322000100',
#   'end_time': '20150323235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.06,
#   'start_time': '20150323000100',
#   'end_time': '20150324235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.06,
#   'start_time': '20150324000100',
#   'end_time': '20150325235900',
#   'next_poll_delta': -0.019999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150325000100',
#   'end_time': '20150326235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150326000100',
#   'end_time': '20150327235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150327000100',
#   'end_time': '20150328235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150328000100',
#   'end_time': '20150329235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150329000100',
#   'end_time': '20150330235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.035,
#   'start_time': '20150330000100',
#   'end_time': '20150331235900',
#   'next_poll_delta': 0.0049999999999999975},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150331000100',
#   'end_time': '20150401235900',
#   'next_poll_delta': 0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.055000000000000014,
#   'start_time': '20150401000100',
#   'end_time': '20150402235900',
#   'next_poll_delta': -0.03500000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150402000100',
#   'end_time': '20150403235900',
#   'next_poll_delta': 0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150403000100',
#   'end_time': '20150404235900',
#   'next_poll_delta': -0.019999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150404000100',
#   'end_time': '20150405235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150405000100',
#   'end_time': '20150406235900',
#   'next_poll_delta': 0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150406000100',
#   'end_time': '20150407235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150407000100',
#   'end_time': '20150408235900',
#   'next_poll_delta': -0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150408000100',
#   'end_time': '20150409235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150409000100',
#   'end_time': '20150410235900',
#   'next_poll_delta': 0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150410000100',
#   'end_time': '20150411235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150411000100',
#   'end_time': '20150412235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150412000100',
#   'end_time': '20150413235900',
#   'next_poll_delta': 0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150413000100',
#   'end_time': '20150414235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150414000100',
#   'end_time': '20150415235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150415000100',
#   'end_time': '20150416235900',
#   'next_poll_delta': -0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150416000100',
#   'end_time': '20150417235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150417000100',
#   'end_time': '20150418235900',
#   'next_poll_delta': -0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150418000100',
#   'end_time': '20150419235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150419000100',
#   'end_time': '20150420235900',
#   'next_poll_delta': 0.025},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.035,
#   'start_time': '20150420000100',
#   'end_time': '20150421235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150421000100',
#   'end_time': '20150422235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150422000100',
#   'end_time': '20150423235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150423000100',
#   'end_time': '20150424235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.06,
#   'start_time': '20150424000100',
#   'end_time': '20150425235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150425000100',
#   'end_time': '20150426235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150426000100',
#   'end_time': '20150427235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150427000100',
#   'end_time': '20150428235900',
#   'next_poll_delta': -0.020000000000000004},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150428000100',
#   'end_time': '20150429235900',
#   'next_poll_delta': -0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150429000100',
#   'end_time': '20150430235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150430000100',
#   'end_time': '20150501235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150501000100',
#   'end_time': '20150502235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150502000100',
#   'end_time': '20150503235900',
#   'next_poll_delta': 0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150503000100',
#   'end_time': '20150504235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150504000100',
#   'end_time': '20150505235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150505000100',
#   'end_time': '20150506235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150506000100',
#   'end_time': '20150507235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150507000100',
#   'end_time': '20150508235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150508000100',
#   'end_time': '20150509235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150509000100',
#   'end_time': '20150510235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150510000100',
#   'end_time': '20150511235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150511000100',
#   'end_time': '20150512235900',
#   'next_poll_delta': -0.02},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150512000100',
#   'end_time': '20150513235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150513000100',
#   'end_time': '20150514235900',
#   'next_poll_delta': 0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150514000100',
#   'end_time': '20150515235900',
#   'next_poll_delta': 0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150515000100',
#   'end_time': '20150516235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150516000100',
#   'end_time': '20150517235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150517000100',
#   'end_time': '20150518235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150518000100',
#   'end_time': '20150519235900',
#   'next_poll_delta': 0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150519000100',
#   'end_time': '20150520235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150520000100',
#   'end_time': '20150521235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150521000100',
#   'end_time': '20150522235900',
#   'next_poll_delta': 0.019999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.06,
#   'start_time': '20150522000100',
#   'end_time': '20150523235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150523000100',
#   'end_time': '20150524235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150524000100',
#   'end_time': '20150525235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150525000100',
#   'end_time': '20150526235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150526000100',
#   'end_time': '20150527235900',
#   'next_poll_delta': -0.02},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150527000100',
#   'end_time': '20150528235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150528000100',
#   'end_time': '20150529235900',
#   'next_poll_delta': -0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150529000100',
#   'end_time': '20150530235900',
#   'next_poll_delta': 0.01666666666666667},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02666666666666667,
#   'start_time': '20150530000100',
#   'end_time': '20150531235900',
#   'next_poll_delta': -0.006666666666666668},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150531000100',
#   'end_time': '20150601235900',
#   'next_poll_delta': 0.005000000000000001},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.025,
#   'start_time': '20150601000100',
#   'end_time': '20150602235900',
#   'next_poll_delta': -0.015000000000000001},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150602000100',
#   'end_time': '20150603235900',
#   'next_poll_delta': 0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150603000100',
#   'end_time': '20150604235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150604000100',
#   'end_time': '20150605235900',
#   'next_poll_delta': 0.02},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.04,
#   'start_time': '20150605000100',
#   'end_time': '20150606235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150606000100',
#   'end_time': '20150607235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150607000100',
#   'end_time': '20150608235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150608000100',
#   'end_time': '20150609235900',
#   'next_poll_delta': -0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150609000100',
#   'end_time': '20150610235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150610000100',
#   'end_time': '20150611235900',
#   'next_poll_delta': -0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150611000100',
#   'end_time': '20150612235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.01,
#   'start_time': '20150612000100',
#   'end_time': '20150613235900',
#   'next_poll_delta': 0.01},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150613000100',
#   'end_time': '20150614235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.02,
#   'start_time': '20150614000100',
#   'end_time': '20150615235900',
#   'next_poll_delta': 0.009999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150615000100',
#   'end_time': '20150616235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150616000100',
#   'end_time': '20150617235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.03,
#   'start_time': '20150617000100',
#   'end_time': '20150618235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.05,
#   'start_time': '20150618000100',
#   'end_time': '20150619235900',
#   'next_poll_delta': 0.039999999999999994},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.09,
#   'start_time': '20150619000100',
#   'end_time': '20150620235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.08,
#   'start_time': '20150620000100',
#   'end_time': '20150621235900',
#   'next_poll_delta': 0.024999999999999994},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.105,
#   'start_time': '20150621000100',
#   'end_time': '20150622235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.11,
#   'start_time': '20150622000100',
#   'end_time': '20150623235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.1,
#   'start_time': '20150623000100',
#   'end_time': '20150624235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.1,
#   'start_time': '20150624000100',
#   'end_time': '20150625235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.12,
#   'start_time': '20150625000100',
#   'end_time': '20150626235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.13,
#   'start_time': '20150626000100',
#   'end_time': '20150627235900',
#   'next_poll_delta': -0.020000000000000004},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.11,
#   'start_time': '20150627000100',
#   'end_time': '20150628235900',
#   'next_poll_delta': 0.015},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.125,
#   'start_time': '20150628000100',
#   'end_time': '20150629235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.12,
#   'start_time': '20150629000100',
#   'end_time': '20150630235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.12,
#   'start_time': '20150630000100',
#   'end_time': '20150701235900',
#   'next_poll_delta': 0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.14,
#   'start_time': '20150701000100',
#   'end_time': '20150702235900',
#   'next_poll_delta': 0.009999999999999981},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.15,
#   'start_time': '20150702000100',
#   'end_time': '20150703235900',
#   'next_poll_delta': -0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.13,
#   'start_time': '20150703000100',
#   'end_time': '20150704235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.12,
#   'start_time': '20150704000100',
#   'end_time': '20150705235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.13,
#   'start_time': '20150705000100',
#   'end_time': '20150706235900',
#   'next_poll_delta': -0.03},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.1,
#   'start_time': '20150706000100',
#   'end_time': '20150707235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.11,
#   'start_time': '20150707000100',
#   'end_time': '20150708235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.12,
#   'start_time': '20150708000100',
#   'end_time': '20150709235900',
#   'next_poll_delta': 0.03},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.15,
#   'start_time': '20150709000100',
#   'end_time': '20150710235900',
#   'next_poll_delta': 0.03},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.18,
#   'start_time': '20150710000100',
#   'end_time': '20150711235900',
#   'next_poll_delta': -0.026666666666666644},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.15333333333333335,
#   'start_time': '20150711000100',
#   'end_time': '20150712235900',
#   'next_poll_delta': 0.011666666666666659},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.165,
#   'start_time': '20150712000100',
#   'end_time': '20150713235900',
#   'next_poll_delta': 0.03},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.195,
#   'start_time': '20150713000100',
#   'end_time': '20150714235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.175,
#   'start_time': '20150714000100',
#   'end_time': '20150715235900',
#   'next_poll_delta': -0.014999999999999986},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.16,
#   'start_time': '20150715000100',
#   'end_time': '20150716235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.17,
#   'start_time': '20150716000100',
#   'end_time': '20150717235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.16,
#   'start_time': '20150717000100',
#   'end_time': '20150718235900',
#   'next_poll_delta': 0.035},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.195,
#   'start_time': '20150718000100',
#   'end_time': '20150719235900',
#   'next_poll_delta': 0.018333333333333313},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.21333333333333332,
#   'start_time': '20150719000100',
#   'end_time': '20150720235900',
#   'next_poll_delta': -0.03833333333333333},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.175,
#   'start_time': '20150720000100',
#   'end_time': '20150721235900',
#   'next_poll_delta': -0.004999999999999977},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.17,
#   'start_time': '20150721000100',
#   'end_time': '20150722235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.19,
#   'start_time': '20150722000100',
#   'end_time': '20150723235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.21,
#   'start_time': '20150723000100',
#   'end_time': '20150724235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.22,
#   'start_time': '20150724000100',
#   'end_time': '20150725235900',
#   'next_poll_delta': 0.060000000000000026},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20150725000100',
#   'end_time': '20150726235900',
#   'next_poll_delta': -0.03500000000000003},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.245,
#   'start_time': '20150726000100',
#   'end_time': '20150727235900',
#   'next_poll_delta': 0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20150727000100',
#   'end_time': '20150728235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20150728000100',
#   'end_time': '20150729235900',
#   'next_poll_delta': -0.04000000000000001},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.22,
#   'start_time': '20150729000100',
#   'end_time': '20150730235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150730000100',
#   'end_time': '20150731235900',
#   'next_poll_delta': 0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20150731000100',
#   'end_time': '20150801235900',
#   'next_poll_delta': -0.04600000000000001},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.234,
#   'start_time': '20150801000100',
#   'end_time': '20150802235900',
#   'next_poll_delta': -0.0040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.23,
#   'start_time': '20150802000100',
#   'end_time': '20150803235900',
#   'next_poll_delta': 0.01666666666666669},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2466666666666667,
#   'start_time': '20150803000100',
#   'end_time': '20150804235900',
#   'next_poll_delta': -0.0266666666666667},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.22,
#   'start_time': '20150804000100',
#   'end_time': '20150805235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.22,
#   'start_time': '20150805000100',
#   'end_time': '20150806235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150806000100',
#   'end_time': '20150807235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150807000100',
#   'end_time': '20150808235900',
#   'next_poll_delta': 0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20150808000100',
#   'end_time': '20150809235900',
#   'next_poll_delta': -0.09000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.18,
#   'start_time': '20150809000100',
#   'end_time': '20150810235900',
#   'next_poll_delta': -0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.16,
#   'start_time': '20150810000100',
#   'end_time': '20150811235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.15,
#   'start_time': '20150811000100',
#   'end_time': '20150812235900',
#   'next_poll_delta': 0.06},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.21,
#   'start_time': '20150812000100',
#   'end_time': '20150813235900',
#   'next_poll_delta': -0.03999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.17,
#   'start_time': '20150813000100',
#   'end_time': '20150814235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.19,
#   'start_time': '20150814000100',
#   'end_time': '20150815235900',
#   'next_poll_delta': 0.07333333333333336},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26333333333333336,
#   'start_time': '20150815000100',
#   'end_time': '20150816235900',
#   'next_poll_delta': -0.023333333333333373},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150816000100',
#   'end_time': '20150817235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150817000100',
#   'end_time': '20150818235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.24,
#   'start_time': '20150818000100',
#   'end_time': '20150819235900',
#   'next_poll_delta': 0.10999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20150819000100',
#   'end_time': '20150820235900',
#   'next_poll_delta': -0.019999999999999962},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150820000100',
#   'end_time': '20150821235900',
#   'next_poll_delta': 0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.355,
#   'start_time': '20150821000100',
#   'end_time': '20150822235900',
#   'next_poll_delta': -0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150822000100',
#   'end_time': '20150823235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.31,
#   'start_time': '20150823000100',
#   'end_time': '20150824235900',
#   'next_poll_delta': -0.019999999999999962},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29000000000000004,
#   'start_time': '20150824000100',
#   'end_time': '20150825235900',
#   'next_poll_delta': 0.03999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150825000100',
#   'end_time': '20150826235900',
#   'next_poll_delta': 0.019999999999999962},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20150826000100',
#   'end_time': '20150827235900',
#   'next_poll_delta': -0.019999999999999962},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150827000100',
#   'end_time': '20150828235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20150828000100',
#   'end_time': '20150829235900',
#   'next_poll_delta': 0.016666666666666607},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3366666666666666,
#   'start_time': '20150829000100',
#   'end_time': '20150830235900',
#   'next_poll_delta': 0.0033333333333334103},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20150830000100',
#   'end_time': '20150831235900',
#   'next_poll_delta': 0.004999999999999949},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.345,
#   'start_time': '20150831000100',
#   'end_time': '20150901235900',
#   'next_poll_delta': -0.014999999999999958},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150901000100',
#   'end_time': '20150902235900',
#   'next_poll_delta': 0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20150902000100',
#   'end_time': '20150903235900',
#   'next_poll_delta': -0.03999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20150903000100',
#   'end_time': '20150904235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20150904000100',
#   'end_time': '20150905235900',
#   'next_poll_delta': 0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20150905000100',
#   'end_time': '20150906235900',
#   'next_poll_delta': -0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.335,
#   'start_time': '20150906000100',
#   'end_time': '20150907235900',
#   'next_poll_delta': -0.0016666666666667052},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3333333333333333,
#   'start_time': '20150907000100',
#   'end_time': '20150908235900',
#   'next_poll_delta': 0.00666666666666671},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20150908000100',
#   'end_time': '20150909235900',
#   'next_poll_delta': 0.004999999999999949},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.345,
#   'start_time': '20150909000100',
#   'end_time': '20150910235900',
#   'next_poll_delta': -0.004999999999999949},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20150910000100',
#   'end_time': '20150911235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20150911000100',
#   'end_time': '20150912235900',
#   'next_poll_delta': 0.0033333333333332993},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3233333333333333,
#   'start_time': '20150912000100',
#   'end_time': '20150913235900',
#   'next_poll_delta': 0.03666666666666668},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20150913000100',
#   'end_time': '20150914235900',
#   'next_poll_delta': -0.019999999999999962},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20150914000100',
#   'end_time': '20150915235900',
#   'next_poll_delta': -0.05500000000000005},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.285,
#   'start_time': '20150915000100',
#   'end_time': '20150916235900',
#   'next_poll_delta': 0.08500000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20150916000100',
#   'end_time': '20150917235900',
#   'next_poll_delta': -0.044999999999999984},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.325,
#   'start_time': '20150917000100',
#   'end_time': '20150918235900',
#   'next_poll_delta': -0.021666666666666612},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3033333333333334,
#   'start_time': '20150918000100',
#   'end_time': '20150919235900',
#   'next_poll_delta': 0.011666666666666603},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.315,
#   'start_time': '20150919000100',
#   'end_time': '20150920235900',
#   'next_poll_delta': -0.0616666666666667},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2533333333333333,
#   'start_time': '20150920000100',
#   'end_time': '20150921235900',
#   'next_poll_delta': 0.00666666666666671},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20150921000100',
#   'end_time': '20150922235900',
#   'next_poll_delta': 0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20150922000100',
#   'end_time': '20150923235900',
#   'next_poll_delta': -0.03500000000000003},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.245,
#   'start_time': '20150923000100',
#   'end_time': '20150924235900',
#   'next_poll_delta': 0.03500000000000003},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20150924000100',
#   'end_time': '20150925235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20150925000100',
#   'end_time': '20150926235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20150926000100',
#   'end_time': '20150927235900',
#   'next_poll_delta': -0.04000000000000001},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.23,
#   'start_time': '20150927000100',
#   'end_time': '20150928235900',
#   'next_poll_delta': 0.014999999999999986},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.245,
#   'start_time': '20150928000100',
#   'end_time': '20150929235900',
#   'next_poll_delta': -0.024999999999999994},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.22,
#   'start_time': '20150929000100',
#   'end_time': '20150930235900',
#   'next_poll_delta': 0.0325},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2525,
#   'start_time': '20150930000100',
#   'end_time': '20151001235900',
#   'next_poll_delta': 0.027500000000000024},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20151001000100',
#   'end_time': '20151002235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20151002000100',
#   'end_time': '20151003235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20151003000100',
#   'end_time': '20151004235900',
#   'next_poll_delta': 0.016666666666666663},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2866666666666667,
#   'start_time': '20151004000100',
#   'end_time': '20151005235900',
#   'next_poll_delta': 0.043333333333333335},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151005000100',
#   'end_time': '20151006235900',
#   'next_poll_delta': -0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151006000100',
#   'end_time': '20151007235900',
#   'next_poll_delta': -0.014999999999999958},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28500000000000003,
#   'start_time': '20151007000100',
#   'end_time': '20151008235900',
#   'next_poll_delta': -0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20151008000100',
#   'end_time': '20151009235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20151009000100',
#   'end_time': '20151010235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20151010000100',
#   'end_time': '20151011235900',
#   'next_poll_delta': 0.025000000000000022},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28500000000000003,
#   'start_time': '20151011000100',
#   'end_time': '20151012235900',
#   'next_poll_delta': 0.014999999999999958},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151012000100',
#   'end_time': '20151013235900',
#   'next_poll_delta': 0.04999999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20151013000100',
#   'end_time': '20151014235900',
#   'next_poll_delta': -0.039999999999999925},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.31000000000000005,
#   'start_time': '20151014000100',
#   'end_time': '20151015235900',
#   'next_poll_delta': 0.07999999999999996},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.39,
#   'start_time': '20151015000100',
#   'end_time': '20151016235900',
#   'next_poll_delta': -0.06},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151016000100',
#   'end_time': '20151017235900',
#   'next_poll_delta': -0.02250000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3075,
#   'start_time': '20151017000100',
#   'end_time': '20151018235900',
#   'next_poll_delta': 0.0675},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.375,
#   'start_time': '20151018000100',
#   'end_time': '20151019235900',
#   'next_poll_delta': -0.034999999999999976},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151019000100',
#   'end_time': '20151020235900',
#   'next_poll_delta': -0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151020000100',
#   'end_time': '20151021235900',
#   'next_poll_delta': -0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.27,
#   'start_time': '20151021000100',
#   'end_time': '20151022235900',
#   'next_poll_delta': 0.06},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151022000100',
#   'end_time': '20151023235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.31,
#   'start_time': '20151023000100',
#   'end_time': '20151024235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29,
#   'start_time': '20151024000100',
#   'end_time': '20151025235900',
#   'next_poll_delta': 0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151025000100',
#   'end_time': '20151026235900',
#   'next_poll_delta': -0.03999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29000000000000004,
#   'start_time': '20151026000100',
#   'end_time': '20151027235900',
#   'next_poll_delta': -0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.25,
#   'start_time': '20151027000100',
#   'end_time': '20151028235900',
#   'next_poll_delta': 0.007500000000000007},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2575,
#   'start_time': '20151028000100',
#   'end_time': '20151029235900',
#   'next_poll_delta': 0.03249999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29,
#   'start_time': '20151029000100',
#   'end_time': '20151030235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.295,
#   'start_time': '20151030000100',
#   'end_time': '20151031235900',
#   'next_poll_delta': 0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.31,
#   'start_time': '20151031000100',
#   'end_time': '20151101235900',
#   'next_poll_delta': -0.034999999999999976},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.275,
#   'start_time': '20151101000100',
#   'end_time': '20151102235900',
#   'next_poll_delta': -0.0016666666666666496},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2733333333333334,
#   'start_time': '20151102000100',
#   'end_time': '20151103235900',
#   'next_poll_delta': -0.018333333333333368},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.255,
#   'start_time': '20151103000100',
#   'end_time': '20151104235900',
#   'next_poll_delta': 0.025000000000000022},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28,
#   'start_time': '20151104000100',
#   'end_time': '20151105235900',
#   'next_poll_delta': -0.03500000000000003},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.245,
#   'start_time': '20151105000100',
#   'end_time': '20151106235900',
#   'next_poll_delta': 0.044999999999999984},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29,
#   'start_time': '20151106000100',
#   'end_time': '20151107235900',
#   'next_poll_delta': 0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20151107000100',
#   'end_time': '20151108235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20151108000100',
#   'end_time': '20151109235900',
#   'next_poll_delta': -0.06},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.26,
#   'start_time': '20151109000100',
#   'end_time': '20151110235900',
#   'next_poll_delta': 0.08000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151110000100',
#   'end_time': '20151111235900',
#   'next_poll_delta': -0.025000000000000022},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.315,
#   'start_time': '20151111000100',
#   'end_time': '20151112235900',
#   'next_poll_delta': 0.034999999999999976},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20151112000100',
#   'end_time': '20151113235900',
#   'next_poll_delta': 0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.39,
#   'start_time': '20151113000100',
#   'end_time': '20151114235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.39,
#   'start_time': '20151114000100',
#   'end_time': '20151115235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20151115000100',
#   'end_time': '20151116235900',
#   'next_poll_delta': -0.09499999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.28500000000000003,
#   'start_time': '20151116000100',
#   'end_time': '20151117235900',
#   'next_poll_delta': 0.07499999999999996},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151117000100',
#   'end_time': '20151118235900',
#   'next_poll_delta': -0.036666666666666625},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32333333333333336,
#   'start_time': '20151118000100',
#   'end_time': '20151119235900',
#   'next_poll_delta': 0.036666666666666625},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151119000100',
#   'end_time': '20151120235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151120000100',
#   'end_time': '20151121235900',
#   'next_poll_delta': -0.03999999999999998},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20151121000100',
#   'end_time': '20151122235900',
#   'next_poll_delta': 0.029999999999999916},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3499999999999999,
#   'start_time': '20151122000100',
#   'end_time': '20151123235900',
#   'next_poll_delta': -0.019999999999999907},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151123000100',
#   'end_time': '20151124235900',
#   'next_poll_delta': -0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151124000100',
#   'end_time': '20151125235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.29,
#   'start_time': '20151125000100',
#   'end_time': '20151126235900',
#   'next_poll_delta': 0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151126000100',
#   'end_time': '20151127235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151127000100',
#   'end_time': '20151128235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151128000100',
#   'end_time': '20151129235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20151129000100',
#   'end_time': '20151130235900',
#   'next_poll_delta': 0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.345,
#   'start_time': '20151130000100',
#   'end_time': '20151201235900',
#   'next_poll_delta': -0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32,
#   'start_time': '20151201000100',
#   'end_time': '20151202235900',
#   'next_poll_delta': -0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.305,
#   'start_time': '20151202000100',
#   'end_time': '20151203235900',
#   'next_poll_delta': 5.551115123125783e-17},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.30500000000000005,
#   'start_time': '20151203000100',
#   'end_time': '20151204235900',
#   'next_poll_delta': 0.024999999999999967},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151204000100',
#   'end_time': '20151205235900',
#   'next_poll_delta': -0.036666666666666736},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.2933333333333333,
#   'start_time': '20151205000100',
#   'end_time': '20151206235900',
#   'next_poll_delta': 0.09000000000000002},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3833333333333333,
#   'start_time': '20151206000100',
#   'end_time': '20151207235900',
#   'next_poll_delta': -0.013333333333333308},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20151207000100',
#   'end_time': '20151208235900',
#   'next_poll_delta': -0.05999999999999994},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.31000000000000005,
#   'start_time': '20151208000100',
#   'end_time': '20151209235900',
#   'next_poll_delta': 0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151209000100',
#   'end_time': '20151210235900',
#   'next_poll_delta': -0.040000000000000036},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151210000100',
#   'end_time': '20151211235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3,
#   'start_time': '20151211000100',
#   'end_time': '20151212235900',
#   'next_poll_delta': 0.07666666666666672},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3766666666666667,
#   'start_time': '20151212000100',
#   'end_time': '20151213235900',
#   'next_poll_delta': -0.01666666666666672},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151213000100',
#   'end_time': '20151214235900',
#   'next_poll_delta': 0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.375,
#   'start_time': '20151214000100',
#   'end_time': '20151215235900',
#   'next_poll_delta': -0.025000000000000022},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20151215000100',
#   'end_time': '20151216235900',
#   'next_poll_delta': 0.0124999999999999},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.3624999999999999,
#   'start_time': '20151216000100',
#   'end_time': '20151217235900',
#   'next_poll_delta': -0.03249999999999986},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151217000100',
#   'end_time': '20151218235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.33,
#   'start_time': '20151218000100',
#   'end_time': '20151219235900',
#   'next_poll_delta': -0.003333333333333355},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.32666666666666666,
#   'start_time': '20151219000100',
#   'end_time': '20151220235900',
#   'next_poll_delta': 0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35666666666666663,
#   'start_time': '20151220000100',
#   'end_time': '20151221235900',
#   'next_poll_delta': 0.003333333333333355},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151221000100',
#   'end_time': '20151222235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20151222000100',
#   'end_time': '20151223235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20151223000100',
#   'end_time': '20151224235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20151224000100',
#   'end_time': '20151225235900',
#   'next_poll_delta': 0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.4,
#   'start_time': '20151225000100',
#   'end_time': '20151226235900',
#   'next_poll_delta': -0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.385,
#   'start_time': '20151226000100',
#   'end_time': '20151227235900',
#   'next_poll_delta': -0.015000000000000013},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20151227000100',
#   'end_time': '20151228235900',
#   'next_poll_delta': -0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.34,
#   'start_time': '20151228000100',
#   'end_time': '20151229235900',
#   'next_poll_delta': 0.009999999999999953},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20151229000100',
#   'end_time': '20151230235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20151230000100',
#   'end_time': '20151231235900',
#   'next_poll_delta': 0.06},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.41,
#   'start_time': '20151231000100',
#   'end_time': '20160102235900',
#   'next_poll_delta': -0.02999999999999997},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20160102000100',
#   'end_time': '20160103235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20160103000100',
#   'end_time': '20160104235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20160104000100',
#   'end_time': '20160105235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.36,
#   'start_time': '20160105000100',
#   'end_time': '20160106235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20160106000100',
#   'end_time': '20160107235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.365,
#   'start_time': '20160107000100',
#   'end_time': '20160108235900',
#   'next_poll_delta': 0.03500000000000003},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.4,
#   'start_time': '20160108000100',
#   'end_time': '20160109235900',
#   'next_poll_delta': -0.008000000000000007},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.392,
#   'start_time': '20160109000100',
#   'end_time': '20160110235900',
#   'next_poll_delta': -0.0020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.39,
#   'start_time': '20160110000100',
#   'end_time': '20160111235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20160111000100',
#   'end_time': '20160112235900',
#   'next_poll_delta': -0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20160112000100',
#   'end_time': '20160113235900',
#   'next_poll_delta': 0.030000000000000027},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.38,
#   'start_time': '20160113000100',
#   'end_time': '20160114235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37,
#   'start_time': '20160114000100',
#   'end_time': '20160115235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.35,
#   'start_time': '20160115000100',
#   'end_time': '20160116235900',
#   'next_poll_delta': 0.026666666666666672},
#  {'candidate': 'Donald Trump',
#   'poll_res': 0.37666666666666665,
#   'start_time': '20160116000100',
#   'end_time': '20160117235900',
# ...
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05333333333333334,
#   'start_time': '20150829000100',
#   'end_time': '20150830235900',
#   'next_poll_delta': 0.01666666666666667},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20150830000100',
#   'end_time': '20150831235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.065,
#   'start_time': '20150831000100',
#   'end_time': '20150901235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07500000000000001,
#   'start_time': '20150901000100',
#   'end_time': '20150902235900',
#   'next_poll_delta': -0.02500000000000001},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150902000100',
#   'end_time': '20150903235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06,
#   'start_time': '20150903000100',
#   'end_time': '20150904235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150904000100',
#   'end_time': '20150905235900',
#   'next_poll_delta': 0.03},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08,
#   'start_time': '20150905000100',
#   'end_time': '20150906235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20150906000100',
#   'end_time': '20150907235900',
#   'next_poll_delta': 0.006666666666666668},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07666666666666667,
#   'start_time': '20150907000100',
#   'end_time': '20150908235900',
#   'next_poll_delta': 0.02333333333333333},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.1,
#   'start_time': '20150908000100',
#   'end_time': '20150909235900',
#   'next_poll_delta': -0.015},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.085,
#   'start_time': '20150909000100',
#   'end_time': '20150910235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08,
#   'start_time': '20150910000100',
#   'end_time': '20150911235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20150911000100',
#   'end_time': '20150912235900',
#   'next_poll_delta': -0.013333333333333357},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05666666666666665,
#   'start_time': '20150912000100',
#   'end_time': '20150913235900',
#   'next_poll_delta': -0.006666666666666647},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150913000100',
#   'end_time': '20150914235900',
#   'next_poll_delta': 0.0049999999999999975},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.055,
#   'start_time': '20150914000100',
#   'end_time': '20150915235900',
#   'next_poll_delta': -0.0049999999999999975},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150915000100',
#   'end_time': '20150916235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.04,
#   'start_time': '20150916000100',
#   'end_time': '20150917235900',
#   'next_poll_delta': 0.02000000000000001},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06000000000000001,
#   'start_time': '20150917000100',
#   'end_time': '20150918235900',
#   'next_poll_delta': -0.0033333333333333617},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05666666666666665,
#   'start_time': '20150918000100',
#   'end_time': '20150919235900',
#   'next_poll_delta': 0.0033333333333333617},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06000000000000001,
#   'start_time': '20150919000100',
#   'end_time': '20150920235900',
#   'next_poll_delta': 0.003333333333333327},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06333333333333334,
#   'start_time': '20150920000100',
#   'end_time': '20150921235900',
#   'next_poll_delta': 0.011666666666666672},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07500000000000001,
#   'start_time': '20150921000100',
#   'end_time': '20150922235900',
#   'next_poll_delta': 0.0049999999999999906},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08,
#   'start_time': '20150922000100',
#   'end_time': '20150923235900',
#   'next_poll_delta': -0.025},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.055,
#   'start_time': '20150923000100',
#   'end_time': '20150924235900',
#   'next_poll_delta': -0.0049999999999999975},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150924000100',
#   'end_time': '20150925235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150925000100',
#   'end_time': '20150926235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150926000100',
#   'end_time': '20150927235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150927000100',
#   'end_time': '20150928235900',
#   'next_poll_delta': 0.015},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.065,
#   'start_time': '20150928000100',
#   'end_time': '20150929235900',
#   'next_poll_delta': -0.015},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20150929000100',
#   'end_time': '20150930235900',
#   'next_poll_delta': 0.022500000000000006},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07250000000000001,
#   'start_time': '20150930000100',
#   'end_time': '20151001235900',
#   'next_poll_delta': 0.017499999999999988},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151001000100',
#   'end_time': '20151002235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08,
#   'start_time': '20151002000100',
#   'end_time': '20151003235900',
#   'next_poll_delta': -0.013333333333333322},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06666666666666668,
#   'start_time': '20151003000100',
#   'end_time': '20151004235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05666666666666668,
#   'start_time': '20151004000100',
#   'end_time': '20151005235900',
#   'next_poll_delta': -0.006666666666666675},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20151005000100',
#   'end_time': '20151006235900',
#   'next_poll_delta': -0.010000000000000002},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.04,
#   'start_time': '20151006000100',
#   'end_time': '20151007235900',
#   'next_poll_delta': 0.04},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08,
#   'start_time': '20151007000100',
#   'end_time': '20151008235900',
#   'next_poll_delta': 0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151008000100',
#   'end_time': '20151009235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.1,
#   'start_time': '20151009000100',
#   'end_time': '20151010235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151010000100',
#   'end_time': '20151011235900',
#   'next_poll_delta': -0.012499999999999997},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.0775,
#   'start_time': '20151011000100',
#   'end_time': '20151012235900',
#   'next_poll_delta': -0.0175},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06,
#   'start_time': '20151012000100',
#   'end_time': '20151013235900',
#   'next_poll_delta': -0.019999999999999997},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.04,
#   'start_time': '20151013000100',
#   'end_time': '20151014235900',
#   'next_poll_delta': 0.015},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.055,
#   'start_time': '20151014000100',
#   'end_time': '20151015235900',
#   'next_poll_delta': 0.015000000000000006},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20151015000100',
#   'end_time': '20151016235900',
#   'next_poll_delta': -0.013333333333333329},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05666666666666668,
#   'start_time': '20151016000100',
#   'end_time': '20151017235900',
#   'next_poll_delta': 0.025833333333333326},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.0825,
#   'start_time': '20151017000100',
#   'end_time': '20151018235900',
#   'next_poll_delta': -0.0175},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.065,
#   'start_time': '20151018000100',
#   'end_time': '20151019235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20151019000100',
#   'end_time': '20151020235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06,
#   'start_time': '20151020000100',
#   'end_time': '20151021235900',
#   'next_poll_delta': -0.004999999999999984},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.055000000000000014,
#   'start_time': '20151021000100',
#   'end_time': '20151022235900',
#   'next_poll_delta': 0.004999999999999984},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06,
#   'start_time': '20151022000100',
#   'end_time': '20151023235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05,
#   'start_time': '20151023000100',
#   'end_time': '20151024235900',
#   'next_poll_delta': 0.003333333333333334},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.05333333333333334,
#   'start_time': '20151024000100',
#   'end_time': '20151025235900',
#   'next_poll_delta': 0.01666666666666667},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20151025000100',
#   'end_time': '20151026235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07500000000000001,
#   'start_time': '20151026000100',
#   'end_time': '20151027235900',
#   'next_poll_delta': -0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07,
#   'start_time': '20151027000100',
#   'end_time': '20151028235900',
#   'next_poll_delta': 0.0175},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.08750000000000001,
#   'start_time': '20151028000100',
#   'end_time': '20151029235900',
#   'next_poll_delta': -0.02750000000000001},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.06,
#   'start_time': '20151029000100',
#   'end_time': '20151030235900',
#   'next_poll_delta': 0.015000000000000013},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.07500000000000001,
#   'start_time': '20151030000100',
#   'end_time': '20151031235900',
#   'next_poll_delta': 0.014999999999999986},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151031000100',
#   'end_time': '20151101235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151101000100',
#   'end_time': '20151102235900',
#   'next_poll_delta': -0.013333333333333322},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09666666666666668,
#   'start_time': '20151102000100',
#   'end_time': '20151103235900',
#   'next_poll_delta': 0.013333333333333322},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151103000100',
#   'end_time': '20151104235900',
#   'next_poll_delta': 0.030000000000000013},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.14,
#   'start_time': '20151104000100',
#   'end_time': '20151105235900',
#   'next_poll_delta': -0.020000000000000018},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.12,
#   'start_time': '20151105000100',
#   'end_time': '20151106235900',
#   'next_poll_delta': -0.009999999999999995},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151106000100',
#   'end_time': '20151107235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151107000100',
#   'end_time': '20151108235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.115,
#   'start_time': '20151108000100',
#   'end_time': '20151109235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.105,
#   'start_time': '20151109000100',
#   'end_time': '20151110235900',
#   'next_poll_delta': 0.0050000000000000044},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151110000100',
#   'end_time': '20151111235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.13,
#   'start_time': '20151111000100',
#   'end_time': '20151112235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.12,
#   'start_time': '20151112000100',
#   'end_time': '20151113235900',
#   'next_poll_delta': -0.03},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151113000100',
#   'end_time': '20151114235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151114000100',
#   'end_time': '20151115235900',
#   'next_poll_delta': -0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.09,
#   'start_time': '20151115000100',
#   'end_time': '20151116235900',
#   'next_poll_delta': 0.04000000000000001},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.13,
#   'start_time': '20151116000100',
#   'end_time': '20151117235900',
#   'next_poll_delta': -0.03},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.1,
#   'start_time': '20151117000100',
#   'end_time': '20151118235900',
#   'next_poll_delta': 0.006666666666666668},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.10666666666666667,
#   'start_time': '20151118000100',
#   'end_time': '20151119235900',
#   'next_poll_delta': 0.003333333333333327},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151119000100',
#   'end_time': '20151120235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.13,
#   'start_time': '20151120000100',
#   'end_time': '20151121235900',
#   'next_poll_delta': 0.04999999999999999},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.18,
#   'start_time': '20151121000100',
#   'end_time': '20151122235900',
#   'next_poll_delta': -0.03666666666666665},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.14333333333333334,
#   'start_time': '20151122000100',
#   'end_time': '20151123235900',
#   'next_poll_delta': 0.05666666666666667},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.2,
#   'start_time': '20151123000100',
#   'end_time': '20151124235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.19,
#   'start_time': '20151124000100',
#   'end_time': '20151125235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.19,
#   'start_time': '20151125000100',
#   'end_time': '20151126235900',
#   'next_poll_delta': -0.06},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.13,
#   'start_time': '20151126000100',
#   'end_time': '20151127235900',
#   'next_poll_delta': 0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.14,
#   'start_time': '20151127000100',
#   'end_time': '20151128235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.16,
#   'start_time': '20151128000100',
#   'end_time': '20151129235900',
#   'next_poll_delta': 0.0},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.16,
#   'start_time': '20151129000100',
#   'end_time': '20151130235900',
#   'next_poll_delta': -0.009999999999999981},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.15000000000000002,
#   'start_time': '20151130000100',
#   'end_time': '20151201235900',
#   'next_poll_delta': -0.010000000000000009},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.14,
#   'start_time': '20151201000100',
#   'end_time': '20151202235900',
#   'next_poll_delta': -0.030000000000000013},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.11,
#   'start_time': '20151202000100',
#   'end_time': '20151203235900',
#   'next_poll_delta': 0.020000000000000004},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.13,
#   'start_time': '20151203000100',
#   'end_time': '20151204235900',
#   'next_poll_delta': 0.01999999999999999},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.15,
#   'start_time': '20151204000100',
#   'end_time': '20151205235900',
#   'next_poll_delta': -0.009999999999999981},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.14,
#   'start_time': '20151205000100',
#   'end_time': '20151206235900',
#   'next_poll_delta': -0.04000000000000001},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.1,
#   'start_time': '20151206000100',
#   'end_time': '20151207235900',
#   'next_poll_delta': 0.05666666666666664},
#  {'candidate': 'Ted Cruz',
#   'poll_res': 0.15666666666666665,
#   'start_time': '20151207000100',
#   'end_time': '20151208235900',
#   'next_poll_delta': 0.020000000000000018},
#  ...]

# %% [markdown]
# # Collect metrics data

# %% [markdown]
# ## Test the objects

# %%
person_metric = GKGPersonPressMetrics(subject = 'Trump', 
                                      start_time = '20150201000000', 
                                      end_time = '20150202000000')
print(person_metric.build_sql())
# Out:
# SELECT V2Tone FROM `gdelt-bq.gdeltv2.gkg` WHERE Persons LIKE('%trump%') AND DATE > 20150201000000 AND DATE <20150202000000 LIMIT 10

# %%
test_d = person_metric.collect_metrics()

# %%
print(test_d)
# Out:
# {'subject': 'Trump', 'start_time': datetime.datetime(2015, 2, 1, 0, 0), 'end_time': datetime.datetime(2015, 2, 2, 0, 0), 'press_count': 0, 'word_count': 0, 'tone_avg': nan, 'pos_score_avg': nan, 'neg_score_avg': nan, 'polarity_avg': nan, 'act_ref_den_avg': nan, 'self_ref_den_avg': nan}

# %% [markdown]
# ## Query BigQuery for press coverage

# %% [markdown]
# ### Read in the poll data

# %%
# Get the pure poll data for 2016
df_polls_2016 = pd.read_csv('../data/pure_poll_data_2016.csv')
df_polls_2016.set_index('end_time', inplace = True)

# %%
df_polls_2016.tail(5)
# Out:
#             Bush  Carson  Christie      Cruz  Fiorina  Huckabee    Kasich  \
# end_time
# 2016-04-29   NaN     NaN       NaN  0.310000      NaN       NaN  0.140000
# 2016-04-30   NaN     NaN       NaN  0.300000      NaN       NaN  0.170000
# 2016-05-01   NaN     NaN       NaN  0.253333      NaN       NaN  0.163333
# 2016-05-02   NaN     NaN       NaN  0.250000      NaN       NaN  0.140000
# 2016-05-03   NaN     NaN       NaN  0.260000      NaN       NaN  0.170000
#
#             Paul  Rubio  Santorum  Trump
# end_time
# 2016-04-29   NaN    NaN       NaN  0.485
# 2016-04-30   NaN    NaN       NaN  0.520
# 2016-05-01   NaN    NaN       NaN  0.530
# 2016-05-02   NaN    NaN       NaN  0.550
# 2016-05-03   NaN    NaN       NaN  0.560

# %% [markdown]
# ### Establish search criteria

# %%
# Define a list of candidates to search media coverage
candidates = ['Donald Trump', 'John Kasich', 'Ted Cruz', 'Marco Rubio', 'Ben Carson', 
              'Jeb Bush', 'Chris Christie', 'Carly Fiorina', 'Rick Santorum', 'Rand Paul', 'Mike Huckabee']
# Start and ending times for the press coverage search corresponding to dates in the poll DataFrame
search_dates  = create_search_dates(df = df_polls_2016)
# GDELT fields to retrieve
fields=['V2Tone']
# Maximum number of articles to return
limit = 2500
dfs_of_metrics = []

# %% [markdown]
# ### Search press coverage for each candidate

# %%
# Grab coverage metrics for each candidate for each day in the interval
#  append the out put to a list of DataFrames
for candidate in candidates:
    df1  = survey_coverage_by_subject_by_day(subject = candidate, start_time = start_time, end_time = end_time,
                                               fields = fields, limit = limit)
    dfs_of_metrics.append(df1)
# Out:
# Retrieving coverage metrics on Donald Trump for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Donald Trump for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Donald Trump for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Donald Trump for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Donald Trump for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Donald Trump for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Donald Trump for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Donald Trump for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on John Kasich for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on John Kasich for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on John Kasich for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on John Kasich for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on John Kasich for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on John Kasich for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on John Kasich for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on John Kasich for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Ted Cruz for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Ted Cruz for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Ted Cruz for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Ted Cruz for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Ted Cruz for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Ted Cruz for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Ted Cruz for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Ted Cruz for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Marco Rubio for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Marco Rubio for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Marco Rubio for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Marco Rubio for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Marco Rubio for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Marco Rubio for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Marco Rubio for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Marco Rubio for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Ben Carson for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Ben Carson for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Ben Carson for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Ben Carson for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Ben Carson for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Ben Carson for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Ben Carson for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Ben Carson for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Jeb Bush for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Jeb Bush for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Jeb Bush for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Jeb Bush for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Jeb Bush for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Jeb Bush for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Jeb Bush for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Jeb Bush for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Chris Christie for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Chris Christie for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Chris Christie for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Chris Christie for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Chris Christie for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Chris Christie for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Chris Christie for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Chris Christie for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Rick Santorum for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Rick Santorum for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Rick Santorum for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Rick Santorum for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Rick Santorum for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Rick Santorum for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Rick Santorum for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Rick Santorum for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Rand Paul for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Rand Paul for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Rand Paul for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Rand Paul for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Rand Paul for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Rand Paul for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Rand Paul for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Rand Paul for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150227000000 to 20150228000000

# %% [markdown]
# # Store in a DataFrame

# %% [markdown]
# ## Concatenate DataFrames

# %%
df_press = pd.concat(dfs_of_metrics, axis = 0, ignore_index = True)

# %%
df_press.shape
# Out:
# (88, 11)

# %%
df_press
# Out:
#           subject start_time   end_time  press_count  word_count  tone_avg  \
# 0    Donald Trump 2015-02-20 2015-02-21            1         877  1.735358
# 1    Donald Trump 2015-02-21 2015-02-22            0           0       NaN
# 2    Donald Trump 2015-02-22 2015-02-23            0           0       NaN
# 3    Donald Trump 2015-02-23 2015-02-24            0           0       NaN
# 4    Donald Trump 2015-02-24 2015-02-25            0           0       NaN
# 5    Donald Trump 2015-02-25 2015-02-26            0           0       NaN
# 6    Donald Trump 2015-02-26 2015-02-27            0           0       NaN
# 7    Donald Trump 2015-02-27 2015-02-28            1         390 -3.424658
# 8     John Kasich 2015-02-20 2015-02-21          283      215576  0.114556
# 9     John Kasich 2015-02-21 2015-02-22          103       71142 -1.370661
# 10    John Kasich 2015-02-22 2015-02-23          133       84655 -1.071046
# 11    John Kasich 2015-02-23 2015-02-24          162      124233 -0.615865
# 12    John Kasich 2015-02-24 2015-02-25          154       78202  0.731193
# 13    John Kasich 2015-02-25 2015-02-26          510      479576 -1.079491
# 14    John Kasich 2015-02-26 2015-02-27          131       82632 -1.516021
# 15    John Kasich 2015-02-27 2015-02-28           93       74251 -0.948538
# 16       Ted Cruz 2015-02-20 2015-02-21          314      228182 -1.061117
# 17       Ted Cruz 2015-02-21 2015-02-22          103       83873 -1.420687
# 18       Ted Cruz 2015-02-22 2015-02-23           98       79421 -0.378870
# 19       Ted Cruz 2015-02-23 2015-02-24          227      196835 -1.017490
# 20       Ted Cruz 2015-02-24 2015-02-25          188      148654 -1.711783
# 21       Ted Cruz 2015-02-25 2015-02-26          659      538861 -1.963297
# 22       Ted Cruz 2015-02-26 2015-02-27          833      603494 -1.077592
# 23       Ted Cruz 2015-02-27 2015-02-28          656      525839 -1.296245
# 24    Marco Rubio 2015-02-20 2015-02-21          573      441549  0.273729
# 25    Marco Rubio 2015-02-21 2015-02-22          272      192404 -0.009843
# 26    Marco Rubio 2015-02-22 2015-02-23           96       85603 -0.821610
# 27    Marco Rubio 2015-02-23 2015-02-24          260      275914 -1.007138
# 28    Marco Rubio 2015-02-24 2015-02-25          311      183538 -0.724763
# 29    Marco Rubio 2015-02-25 2015-02-26          251      217864 -0.901412
# ..            ...        ...        ...          ...         ...       ...
# 58  Carly Fiorina 2015-02-22 2015-02-23            9       16780 -0.603811
# 59  Carly Fiorina 2015-02-23 2015-02-24           33       30588 -0.607554
# 60  Carly Fiorina 2015-02-24 2015-02-25           25       20288  0.052924
# 61  Carly Fiorina 2015-02-25 2015-02-26           38       24125 -0.275696
# 62  Carly Fiorina 2015-02-26 2015-02-27          368      267157 -0.210337
# 63  Carly Fiorina 2015-02-27 2015-02-28          325      302568 -0.768349
# 64  Rick Santorum 2015-02-20 2015-02-21           73       48661 -0.233631
# 65  Rick Santorum 2015-02-21 2015-02-22           35       21171 -0.312910
# 66  Rick Santorum 2015-02-22 2015-02-23           34       24150 -0.859264
# 67  Rick Santorum 2015-02-23 2015-02-24           67       60831 -0.130813
# 68  Rick Santorum 2015-02-24 2015-02-25           35       33961 -0.469626
# 69  Rick Santorum 2015-02-25 2015-02-26           96       54270  0.022806
# 70  Rick Santorum 2015-02-26 2015-02-27          207      191081  1.262762
# 71  Rick Santorum 2015-02-27 2015-02-28          233      148594 -1.230656
# 72      Rand Paul 2015-02-20 2015-02-21            0           0       NaN
# 73      Rand Paul 2015-02-21 2015-02-22            0           0       NaN
# 74      Rand Paul 2015-02-22 2015-02-23            0           0       NaN
# 75      Rand Paul 2015-02-23 2015-02-24            0           0       NaN
# 76      Rand Paul 2015-02-24 2015-02-25            0           0       NaN
# 77      Rand Paul 2015-02-25 2015-02-26            0           0       NaN
# 78      Rand Paul 2015-02-26 2015-02-27            0           0       NaN
# 79      Rand Paul 2015-02-27 2015-02-28            1         332 -1.089918
# 80  Mike Huckabee 2015-02-20 2015-02-21           95       84533 -1.069398
# 81  Mike Huckabee 2015-02-21 2015-02-22          171      141232  0.925012
# 82  Mike Huckabee 2015-02-22 2015-02-23           75       60150 -0.878827
# 83  Mike Huckabee 2015-02-23 2015-02-24          157      165173 -1.186676
# 84  Mike Huckabee 2015-02-24 2015-02-25          106       90686 -1.025913
# 85  Mike Huckabee 2015-02-25 2015-02-26          187      120814 -0.074080
# 86  Mike Huckabee 2015-02-26 2015-02-27          227      216078  0.977796
# 87  Mike Huckabee 2015-02-27 2015-02-28           68       66537  0.420883
#
#     pos_score_avg  neg_score_avg  polarity_avg  act_ref_den_avg  \
# 0        4.121475       2.386117      6.507592        24.945770
# 1             NaN            NaN           NaN              NaN
# 2             NaN            NaN           NaN              NaN
# 3             NaN            NaN           NaN              NaN
# 4             NaN            NaN           NaN              NaN
# 5             NaN            NaN           NaN              NaN
# 6             NaN            NaN           NaN              NaN
# 7        2.511416       5.936073      8.447489        20.776256
# 8        2.497483       2.382927      4.880410        22.512529
# 9        2.017770       3.388431      5.406202        21.231503
# 10       2.150520       3.221566      5.372086        22.174882
# 11       2.538020       3.153885      5.691906        22.465179
# 12       3.087231       2.356038      5.443269        21.153061
# 13       2.931032       4.010523      6.941556        22.607504
# 14       2.197900       3.713921      5.911821        23.032336
# 15       2.753222       3.701761      6.454983        22.945405
# 16       2.515740       3.576857      6.092597        21.112540
# 17       2.643475       4.064161      6.707636        21.512708
# 18       2.898096       3.276966      6.175062        21.524739
# 19       2.301405       3.318894      5.620299        22.206796
# 20       2.377462       4.089245      6.466707        21.969296
# 21       2.027878       3.991175      6.019053        23.466077
# 22       2.697704       3.775296      6.473000        22.480874
# 23       2.966607       4.262852      7.229460        22.044393
# 24       2.645635       2.371906      5.017540        21.677451
# 25       2.840655       2.850499      5.691154        21.723361
# 26       2.609481       3.431091      6.040572        22.546728
# 27       2.568505       3.575643      6.144147        22.435988
# 28       2.232440       2.957203      5.189643        21.044786
# 29       2.940769       3.842181      6.782950        21.339918
# ..            ...            ...           ...              ...
# 58       2.430807       3.034618      5.465425        19.094457
# 59       2.495584       3.103138      5.598721        20.700033
# 60       2.794237       2.741313      5.535550        21.735240
# 61       2.731768       3.007464      5.739232        20.239409
# 62       2.842752       3.053090      5.895842        21.513761
# 63       3.245488       4.013837      7.259325        21.354478
# 64       2.903002       3.136633      6.039634        22.961117
# 65       2.648013       2.960924      5.608937        21.409535
# 66       2.685814       3.545078      6.230892        21.598453
# 67       2.563033       2.693846      5.256879        21.236653
# 68       2.571314       3.040940      5.612254        21.008425
# 69       2.726087       2.703281      5.429368        20.808704
# 70       3.445640       2.182878      5.628519        21.488807
# 71       2.808447       4.039103      6.847550        21.367541
# 72            NaN            NaN           NaN              NaN
# 73            NaN            NaN           NaN              NaN
# 74            NaN            NaN           NaN              NaN
# 75            NaN            NaN           NaN              NaN
# 76            NaN            NaN           NaN              NaN
# 77            NaN            NaN           NaN              NaN
# 78            NaN            NaN           NaN              NaN
# 79       2.179837       3.269755      5.449591        22.343324
# 80       2.580606       3.650004      6.230610        21.265435
# 81       3.171253       2.246241      5.417494        21.073519
# 82       2.845606       3.724433      6.570039        22.127830
# 83       2.644426       3.831102      6.475527        23.260817
# 84       2.652118       3.678031      6.330149        21.446463
# 85       2.751281       2.825361      5.576642        20.622773
# 86       3.355576       2.377780      5.733355        21.514656
# 87       3.028382       2.607499      5.635882        21.381096
#
#     self_ref_den_avg
# 0           3.253796
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7           0.456621
# 8           0.811196
# 9           0.690252
# 10          0.918156
# 11          0.816513
# 12          0.553149
# 13          1.003572
# 14          0.885240
# 15          0.824511
# 16          0.921171
# 17          1.022015
# 18          0.833090
# 19          0.564826
# 20          0.825058
# 21          0.525313
# 22          0.740611
# 23          1.129023
# 24          0.812255
# 25          0.862731
# 26          0.902432
# 27          0.851297
# 28          1.235201
# 29          0.453810
# ..               ...
# 58          1.644184
# 59          0.645144
# 60          0.524559
# 61          0.719618
# 62          0.763073
# 63          0.951031
# 64          1.041727
# 65          0.628587
# 66          1.151812
# 67          0.877513
# 68          0.597170
# 69          0.300989
# 70          0.672615
# 71          1.103145
# 72               NaN
# 73               NaN
# 74               NaN
# 75               NaN
# 76               NaN
# 77               NaN
# 78               NaN
# 79          1.362398
# 80          0.659335
# 81          0.771459
# 82          0.852347
# 83          0.895611
# 84          0.809745
# 85          0.491374
# 86          0.772665
# 87          0.911710
#
# [88 rows x 11 columns]
