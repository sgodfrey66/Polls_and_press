# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#References" data-toc-modified-id="References-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>References</a></span></li><li><span><a href="#Reading-data-from-GDELT-GKG" data-toc-modified-id="Reading-data-from-GDELT-GKG-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reading data from GDELT GKG</a></span><ul class="toc-item"><li><span><a href="#Class-objects" data-toc-modified-id="Class-objects-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Class objects</a></span></li><li><span><a href="#Search-string" data-toc-modified-id="Search-string-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Search string</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#References" data-toc-modified-id="References-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>References</a></span></li></ul></li><li><span><a href="#Establish-programming-components" data-toc-modified-id="Establish-programming-components-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Establish programming components</a></span><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Establish-parameters" data-toc-modified-id="Establish-parameters-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Establish parameters</a></span></li><li><span><a href="#GDELT-fields-available-from-Google-BigQuery" data-toc-modified-id="GDELT-fields-available-from-Google-BigQuery-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>GDELT fields available from Google BigQuery</a></span></li><li><span><a href="#Establish-classes" data-toc-modified-id="Establish-classes-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Establish classes</a></span></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Define functions</a></span></li></ul></li><li><span><a href="#Collect-metrics-data" data-toc-modified-id="Collect-metrics-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Collect metrics data</a></span><ul class="toc-item"><li><span><a href="#Query-BigQuery-for-press-coverage-and-save-to-BigQuery-table" data-toc-modified-id="Query-BigQuery-for-press-coverage-and-save-to-BigQuery-table-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Query BigQuery for press coverage and save to BigQuery table</a></span><ul class="toc-item"><li><span><a href="#Run-one-time-GDELT-GKG-query-to-get-press-coverage" data-toc-modified-id="Run-one-time-GDELT-GKG-query-to-get-press-coverage-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Run one-time GDELT GKG query to get press coverage</a></span></li><li><span><a href="#Get-the-size-of-the-table" data-toc-modified-id="Get-the-size-of-the-table-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Get the size of the table</a></span></li></ul></li><li><span><a href="#Load-in-the-2016-poll-data" data-toc-modified-id="Load-in-the-2016-poll-data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Load in the 2016 poll data</a></span></li><li><span><a href="#Test-the-objects" data-toc-modified-id="Test-the-objects-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Test the objects</a></span><ul class="toc-item"><li><span><a href="#Create-the-poll-data-intervals" data-toc-modified-id="Create-the-poll-data-intervals-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Create the poll data intervals</a></span></li><li><span><a href="#Create-the-search-parameters" data-toc-modified-id="Create-the-search-parameters-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Create the search parameters</a></span></li><li><span><a href="#Test-the-method-for-retrieving-data" data-toc-modified-id="Test-the-method-for-retrieving-data-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Test the method for retrieving data</a></span></li></ul></li></ul></li><li><span><a href="#Gather-press-data" data-toc-modified-id="Gather-press-data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Gather press data</a></span><ul class="toc-item"><li><span><a href="#Input-parameters" data-toc-modified-id="Input-parameters-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Input parameters</a></span></li><li><span><a href="#Run-the-search-function" data-toc-modified-id="Run-the-search-function-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run the search function</a></span><ul class="toc-item"><li><span><a href="#remove---Establish-search-criteria" data-toc-modified-id="remove---Establish-search-criteria-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>remove - Establish search criteria</a></span></li><li><span><a href="#remove---Search-press-coverage-for-each-candidate" data-toc-modified-id="remove---Search-press-coverage-for-each-candidate-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>remove - Search press coverage for each candidate</a></span></li></ul></li></ul></li><li><span><a href="#Store-in-a-DataFrame" data-toc-modified-id="Store-in-a-DataFrame-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Store in a DataFrame</a></span><ul class="toc-item"><li><span><a href="#Concatenate-DataFrames" data-toc-modified-id="Concatenate-DataFrames-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Concatenate DataFrames</a></span></li></ul></li></ul></div>

# %% [markdown]
# # References
#
# # Reading data from GDELT GKG
#
# This module uses Google's BigQuery application programming interface (API) to pull press coverage data from the Global Data on Events Language and Tone (GDELT) Global Knowledge Graph Version 2 (GKG V2) database.  Specifically, it pulls specific press coverage metrics of individual subjects including article and word counts and the GDELT CKG values for tone, positive and negative scores, polarity and activity reference density and self reference density. More information on these scores can be found in the GDELT [documentation](http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_Codebook-V2.1.pdf)
#
# It stores these data in a DataFrame and outputs them to a comma separated value (CSV) file.
#
#
# ## Class objects
#
# To retrieve the coverage metrics, this code employs a class object designed to interact the Google BigQuery Python [API](https://cloud.google.com/bigquery/docs/reference/libraries) and to query the GDELT GKG database.  The class object is GKGPersonPressMetrics and it is developed to retrieve and store in memory press coverage metrics for an individual.  It is built using Google tools including the aforementioned API and the BigQuery public datasets which include GDELT [tables](https://www.gdeltproject.org/data.html#googlebigquery).
#
#    * GKGPersonPressMetrics attributes:
#        * table - the GDELT GKG V2 table at Google BigQuery
#        * subject - the name of the individual for whom metrics will be retrieved
#        * start_time - the beginning date/time for the search window
#        * end_time - the ending date/time for the search window
#        * fields - the GKG V2 fields to retrieve with the query
#        * query - the SQL query statement
#        * limit - the maximum number of results to return
#        * metrics_ - a dictionary of the returned metrics
#
#
#    * GKGPersonPressMetrics methods:
#        * build_sql() - build the SQL statement used in the press metric search
#        * collect_metrics() - execute the search and return a dictionary of metrics
#
# ## Search string
#
# The GKGPersonPressMetrics object uses a base search string which consists of the following criteria:
#
#    * Select the specified columns from the GKG V2 table
#    * Where the GKG V2 Persons field is searched for names matching the subject
#    * And the dates fall within the specified interval
#    * Limit the returned output to a maximum
#
#
#
# ## Data
#
# The data delineated below are the returned and calculated press metrics.
#
# |Column        |Description    |
# |-----------------|--------------------|
# |Subject  | name of the individual searched in the Persons field|
# |start_time| a datetime object of the search window's start|
# |end_time|  a datetime object of the search window's end|
# |press_count  | the count of articles including the subject's name and within the time interval|
# |word_count| the sum of the word counts of returned articles|
# |tone_avg| the average of GDELT's tone measure for the returned articles|
# |pos_score_avg  |the average of GDELT's positive score for the returned articles|
# |neg_score_avg| the average of GDELT's negative score for the returned articles|
# |polarity_avg| the average of GDELT's polarity measure for the returned articles|
# |act_ref_den_avg  | the average of GDELT's active reference density measure for the returned articles|
# |self_ref_den_avg|  the average of GDELT's self reference density measure for the returned articles|
#
#
# ## References
#
# - https://cloud.google.com/bigquery/docs/reference/libraries#client-libraries-install-python
# - https://pandas-gbq.readthedocs.io/en/latest/index.html
# - http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_Codebook-V2.1.pdf
# - https://blog.gdeltproject.org/introducing-the-global-content-analysis-measures-gcam/
# - https://ivmooc.cns.iu.edu/docs/gdelt-results.pdf
# - http://data.gdeltproject.org/documentation/GDELT-Global_Knowledge_Graph_CategoryList.xlsx
# - https://stackoverflow.com/questions/51967429/understanding-themes-in-google-bigquery-gdelt-gkg-2-0
# - https://stackoverflow.com/questions/45157521/insert-an-item-into-a-specific-location-in-a-dict-in-a-single-statement
# - https://github.com/googleapis/google-cloud-python/issues/5866

# %% [markdown]
# # Establish programming components

# %% [markdown]
# ## Import libraries

# %%
# !pip install --upgrade google-cloud-bigquery
#!pip install versioneer
#!pip install git+https://github.com/pydata/pandas-gbq.git - followed conda install instructions

#import versioneer
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sqlalchemy import create_engine
import psycopg2
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas_gbq
import time
from time import sleep
import re

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Establish parameters

# %% [markdown]
# ## GDELT fields available from Google BigQuery

# %%
'''   
GKGRECORDID	STRING	NULLABLE	
DATE	INTEGER	NULLABLE	
SourceCollectionIdentifier	INTEGER	NULLABLE	
SourceCommonName	STRING	NULLABLE	
DocumentIdentifier	STRING	NULLABLE	
Counts	STRING	NULLABLE	
V2Counts	STRING	NULLABLE	
Themes	STRING	NULLABLE	
V2Themes	STRING	NULLABLE	
Locations	STRING	NULLABLE	
V2Locations	STRING	NULLABLE	
Persons	STRING	NULLABLE	
V2Persons	STRING	NULLABLE	
Organizations	STRING	NULLABLE	
V2Organizations	STRING	NULLABLE	
V2Tone	STRING	NULLABLE	
Dates	STRING	NULLABLE	
GCAM	STRING	NULLABLE	.
SharingImage	STRING	NULLABLE	
RelatedImages	STRING	NULLABLE	.
SocialImageEmbeds	STRING	NULLABLE	
SocialVideoEmbeds	STRING	NULLABLE	
Quotations	STRING	NULLABLE	
AllNames	STRING	NULLABLE	
Amounts	STRING	NULLABLE	.
TranslationInfo	STRING	NULLABLE	
Extras
'''
# Out:
# '   \nGKGRECORDID\tSTRING\tNULLABLE\t\nDATE\tINTEGER\tNULLABLE\t\nSourceCollectionIdentifier\tINTEGER\tNULLABLE\t\nSourceCommonName\tSTRING\tNULLABLE\t\nDocumentIdentifier\tSTRING\tNULLABLE\t\nCounts\tSTRING\tNULLABLE\t\nV2Counts\tSTRING\tNULLABLE\t\nThemes\tSTRING\tNULLABLE\t\nV2Themes\tSTRING\tNULLABLE\t\nLocations\tSTRING\tNULLABLE\t\nV2Locations\tSTRING\tNULLABLE\t\nPersons\tSTRING\tNULLABLE\t\nV2Persons\tSTRING\tNULLABLE\t\nOrganizations\tSTRING\tNULLABLE\t\nV2Organizations\tSTRING\tNULLABLE\t\nV2Tone\tSTRING\tNULLABLE\t\nDates\tSTRING\tNULLABLE\t\nGCAM\tSTRING\tNULLABLE\t.\nSharingImage\tSTRING\tNULLABLE\t\nRelatedImages\tSTRING\tNULLABLE\t.\nSocialImageEmbeds\tSTRING\tNULLABLE\t\nSocialVideoEmbeds\tSTRING\tNULLABLE\t\nQuotations\tSTRING\tNULLABLE\t\nAllNames\tSTRING\tNULLABLE\t\nAmounts\tSTRING\tNULLABLE\t.\nTranslationInfo\tSTRING\tNULLABLE\t\nExtras\n'

# %%
# Environment variables for the Google BigQuery API
bq_cred = '/Users/stephengodfrey/Documents/SteveSchool/dsi/GoogleCloud/BigQuery/CampFireAnalysis-c65ccd07c4d9.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = bq_cred

credentials = service_account.Credentials.from_service_account_file(bq_cred,)

# dataset_id = 'campfireanalysis:rep_primary_press_coverage_2016'
# table_id = 't1'


# # Instantiate the object
# client = bigquery.Client()

# # Configure BigQuery
# job_config = bigquery.QueryJobConfig()
# # Set the destination table
# table_ref = client.dataset(dataset_id).table(table_id)
# job_config.destination = table_ref
# job_config.allow_large_results = True
# job_config.write_disposition = 'WRITE_APPEND'


# conn_str = 'postgres://postgres:' + str(password) + '@54.200.180.8:5432'
conn_str = 'postgres://postgres:A%A$TSHBSA@54.200.180.8:5432'

# Database engine
engine = create_engine(conn_str)

# %% [markdown]
# ## Establish classes

# %%
class GKGPersonPressMetrics:
    # Attributes of the data retrieval
    search_table = "`campfireanalysis.rep_primary_press_coverage_2016.t1`"
    search_paramaters = {}
    fields = []
    time_intervals = {}
    query = ''
    limit = None
    metrics_ = []
    
    # Initialization method
    def __init__(self, search_table = '', search_parameters = {}, 
                 fields = [], limit = None, time_intervals = {}):
        # update self variables
        if search_table != '':
            self.search_table = search_table
        if len(search_parameters) != 0:
            self.search_parameters = search_parameters        
        if len(fields) != 0:
            self.fields = fields
        if limit != None:
            self.limit = limit
        if time_intervals != '':
            self.time_intervals = time_intervals    
      
    
    # Build the SQL string
    def build_sql(self):
        # Construct the select statement
        sel_stm = "SELECT DISTINCT " + ", ".join(self.fields) + " FROM " + self.search_table + " "
        # Construct the subject statement
        sub_stm = "WHERE Persons LIKE('%" + self.search_parameters['subject'].lower() + "%') " 
        # Construct the time statement
        time_stm = "AND DATE > " + self.search_parameters['search_times'][0] + \
                   " AND DATE < " + self.search_parameters['search_times'][1] 
        order_stm = " ORDER BY Date"
        # Construct the limit statement
        if self.limit == None:
            limit_stm = ''
        else:
            limit_stm = " LIMIT "+str(self.limit)

        # Construct a query given the attributes of the class       
        self.query = sel_stm + sub_stm + time_stm + order_stm + limit_stm
        return self.query
        
    
    # method to collect data from posts
    def collect_metrics(self):
        
        # Instantiate the object
        client = bigquery.Client()
        
        # Run the query
        query_job = client.query(self.query, location="US")

        # Check for errors
        if query_job.errors != None:
            if query_job.errors[0]['reason'] == 'invalidQuery':
                # Try to build the sql then run the query again
                self.build_sql()               
                query_job = client.query(self.query, location="US")
            if query_job.errors != None:
                print(query_job.errors)
                raise ValueError('Error with query: ' + query_job.errors[0]['reason'])           

        # Wait for job to finish
        query_job.result()

        # Examine each row returned from the query
        metric = {}
        time_keys = []
        metrics = []
        
        # Build dictionaries for each sub interval in this search window
        for sub_interval in self.search_parameters['sub_dates']:
            time_key = sub_interval[1]
            time_keys.append(time_key)
            metric[time_key] = {}
            metric[time_key]['art_count'] = 0
            metric[time_key]['tone_avg'] = 0
            metric[time_key]['pos_score_avg'] = 0
            metric[time_key]['neg_score_avg'] = 0
            metric[time_key]['polarity_avg'] = 0
            metric[time_key]['act_ref_den_avg'] = 0
            metric[time_key]['self_ref_den_avg'] = 0
            metric[time_key]['word_count'] = 0
            metric[time_key]['themes'] = []

        # Row by row retrieve the returned articles
        for row in query_job:
            # Get the interval key for the this time stamp 
            time_key = interval_key(time = row.get('Date'), times = self.time_intervals)
                      
            # Get the tone metrics from the V2Tone column and store in a dictionary
            #  and keep track of the number of articles in this time_key using count
            try:
                tone_metrics = row.get('V2Tone').split(',')
                metric[time_key]['art_count'] += 1
                metric[time_key]['tone_avg'] += float(tone_metrics[0])
                metric[time_key]['pos_score_avg'] += float(tone_metrics[1])
                metric[time_key]['neg_score_avg'] += float(tone_metrics[2])
                metric[time_key]['polarity_avg'] += float(tone_metrics[3])
                metric[time_key]['act_ref_den_avg'] += float(tone_metrics[4])
                metric[time_key]['self_ref_den_avg'] += float(tone_metrics[5])
                metric[time_key]['word_count'] += float(tone_metrics[6])
            except:
                pass
            
            # Get the themes
            if row.get('V2Themes') == None or len(metric[time_key]['themes']) > 2_000:
                pass
            else:
                metric[time_key]['themes'] += extract_themes(row.get('V2Themes'))
            
        # for each time_key in time_keys add some more values to the dictionaries
        for time_key in time_keys:
            # Add the subject to the dictionary
            metric[time_key]['subject'] = self.search_parameters['subject']

            # Store the average tonal scores
            if metric[time_key]['art_count'] != 0:
                metric[time_key]['tone_avg'] = metric[time_key]['tone_avg']/metric[time_key]['art_count']
                metric[time_key]['pos_score_avg'] = metric[time_key]['pos_score_avg']/metric[time_key]['art_count']
                metric[time_key]['neg_score_avg'] = metric[time_key]['neg_score_avg']/metric[time_key]['art_count']
                metric[time_key]['polarity_avg'] = metric[time_key]['polarity_avg']/metric[time_key]['art_count']
                metric[time_key]['act_ref_den_avg'] = metric[time_key]['act_ref_den_avg']/metric[time_key]['art_count']
                metric[time_key]['self_ref_den_avg'] = metric[time_key]['self_ref_den_avg']/metric[time_key]['art_count']
            else:
                metric[time_key]['tone_avg'] = np.NaN
                metric[time_key]['pos_score_avg'] = np.NaN
                metric[time_key]['neg_score_avg'] = np.NaN
                metric[time_key]['polarity_avg'] = np.NaN
                metric[time_key]['act_ref_den_avg'] = np.NaN
                metric[time_key]['self_ref_den_avg'] = np.NaN
       
        # Return the list of dictionaries
        self.metrics_ = metric
        return metric

    
# Use BigQuery to get press information from the search_table and store it 
#  in the table on the dataset
class PressInventory:   
    # Table to search from
    search_table = ''
    # Dataset and table to write to
    dataset_id = ''
    table_id = ''   
    # List of subjects
    subjects = []
    # Tuple of start and end times
    search_times = ()
    # GDELT fields to retrieve
    fields=[]
    # Maximum number of articles to return
    limit = None
    
    # Initialization method
    def __init__(self, search_table = '', dataset_id = '', table_id = '',
                 subjects = [], search_times = [], fields = [], limit = None):
        
        # update class variables        
        if search_table != '':
            self.search_table = search_table
        if dataset_id != '':
            self.dataset_id = dataset_id
        if table_id != '':
            self.table_id = table_id
        if len(subjects) != 0:
            self.subjects = subjects
        if len(search_times) != 0:
            self.search_times = search_times     
        if len(fields) != 0:
            self.fields = fields
        if limit != None:
            self.limit = limit 
                 
    # Build the SQL string
    def build_sql(self):
        # Construct the select statement
        sel_stm = "SELECT DISTINCT " + ", ".join(self.fields) + " FROM " + self.search_table + " "
        # Construct the subject statement
        sub_stm = ["Persons LIKE('%" + subject.lower() +"%') OR" for subject in self.subjects[:-1]]
        sub_stm = "WHERE " + " ".join(sub_stm) + " Persons LIKE('%" + self.subjects[-1].lower() +"%')"
        # Construct the time statement
        time_stm = " AND DATE > " + self.search_times[0] + " AND DATE < " + self.search_times[1]
        # Construct the limit statement
        if self.limit == None:
            limit_stm = ''
        else:
            limit_stm = " LIMIT "+str(self.limit)
            
        # Construct a query given the attributes of the class       
        self.query = sel_stm + sub_stm + time_stm + limit_stm
        return self.query
    
    
    def collect_coverage(self):      
        
        # Instantiate the object
        client = bigquery.Client()

        # Configure BigQuery
        job_config = bigquery.QueryJobConfig()
        # Set the destination table
        table_ref = client.dataset(self.dataset_id).table(self.table_id)
        job_config.destination = table_ref
        # Set job parameters
        job_config.allow_large_results = True
        job_config.write_disposition = 'WRITE_APPEND'

        # Run the query
        query_job = client.query(self.query, 
                                 location="US",
                                 job_config=job_config)
                
        # Check for errors
        if query_job.errors != None:
            if query_job.errors[0]['reason'] == 'invalidQuery':
                # Try to build the sql then run the query again
                self.build_sql()               
                # Run the query
                query_job = client.query(self.query, 
                                         location="US",
                                         job_config=job_config)
            if query_job.errors != None:
                print(query_job.errors)
                raise ValueError('Error with query: ' + query_job.errors[0]['reason'])           
        
        # Wait for job to finish
        query_job.result()
        print('Query results loaded to table {}'.format(table_ref.path))
                
        return

# %% [markdown]
# ## Define functions

# %%
# Retrieve press coverage metrics for a particular candidate
def build_coverage_dataframe(df_polls = None, subject_mapping = {}, intervals = 1,
                             search_table = '', fields =[], search_limit = None,
                             data_path = ''):
 
    # Establish the preferred order of columns
    cols = ['subject','art_count','word_count','tone_avg','pos_score_avg','neg_score_avg',
            'polarity_avg','act_ref_den_avg','self_ref_den_avg','themes']    
    
    # Use the poll dataframe to create polling intervals to 
    #  get the starting and ending times for each poll indexed by ending date 
    poll_intervals = create_poll_intervals(df = df_polls)
    
    # Create a list of search parameters which
    #  sets the subject of each search to one of the candidates
    #  determines search times by breaking the full polling window into n intervals
    #  if the candidate has no poll data for every date in the search window, no entry is created
    search_params = create_search_parameters(df = df_polls, subjects = subject_mapping, intervals = intervals)
    
    # For each set of search parameters
    df_collection = []
    for search_param in search_params[:2]:
        

        # Instantiate an search object for this set of search parameters
        person_metric = GKGPersonPressMetrics(search_table=search_table, 
                                              search_parameters = search_param, fields = fields, 
                                              limit=search_limit, time_intervals = poll_intervals)
        # Build the SQL string for this search
        person_metric.build_sql()
        
        # Return a list of dictionaries for this search
        this_search = person_metric.collect_metrics()
        
        # Convert this to a DataFrame
        this_df  = pd.DataFrame(this_search).T
        
        # rearrange the columns
        this_df = this_df[cols]
        
        # Save the search results to a csv as a backup
        file_name = search_param['subject'] + '_' + search_param['search_times'][0] + '_' + \
                    search_param['search_times'][1] + '.csv'
        this_df.to_csv(os.path.join(data_path,file_name))
        
        # Append this DataFrame to the list of DataFrames
        df_collection.append(this_df)
        
    # Return a single DataFrame
    return pd.concat(df_collection, axis = 0)




# # Create a list of tuples with start and end date
# def create_search_dates(df = None):
#     # Set the first date to the first date in the index - 7 days + 1 minute
#     first_date = datetime.strptime(df.index[0],'%Y-%m-%d')-timedelta(days=7)+timedelta(minutes=1)
#     first_date = first_date.strftime('%Y-%m-%d%H%M%S')
#     # Create a list of tuples with start and end dates for each interval
#     search_dates = [(i.replace('-','')+'000100',j.replace('-','')+'235900') \
#                     for i,j in zip(df.index[:-1],df.index[1:])]
#     # Add the first date into the list
#     search_dates.insert(0,(first_date,df.index[0].replace('-','')+'235900'))
#     return search_dates


def create_search_parameters(df = None, subjects = {}, intervals = 1):
     
    # Set the first date to the first date in the index - 7 days + 1 minute
    start_time = datetime.strptime(df.index[0],'%Y-%m-%d')-timedelta(days=7)+timedelta(minutes=1)
    start_date = start_time.strftime('%Y-%m-%d')
    start_time = start_time.strftime('%Y%m%d%H%M%S')
   
    # Break the survey window interval into intervals
    n_breaks = df.shape[0]//intervals
    int_points = [i*n_breaks for i in range(intervals)]
    if df.shape[0]/intervals != 0:
        int_points.append(df.shape[0] - 1 )
    
    # Create a dictionary of search times indexed by the last date in the window
    times = {df.index[j].replace('-','')+'000000': (df.index[i].replace('-','')+'000100', 
             df.index[j].replace('-','')+'235900') for i,j in zip(int_points[:-1],int_points[1:])}
    times[df.index[0].replace('-','')+'000000'] = (start_time,df.index[0].replace('-','')+'235900')
       
    # Create a dictionary that contains the poll periods within each time
    sub_times = {}
    sub_times[df.index[int_points[0]].replace('-','')+'000000'] = [(start_date, df.index[0])]
    for k in range(len(int_points)-1):
        this_interval = [(df.index[i], df.index[i+1]) for i in range(int_points[k],int_points[k+1])]
        sub_times[df.index[int_points[k+1]].replace('-','')+'000000'] = this_interval
    
    # For each candidate and create a search entry if poll results at beginning and end of the interval
    search_params = []
    for subject in subjects.keys():
        # Get the column for this subject
        col_i = df.columns.get_loc(subject)
        
        # Look through each search window
        for i, idx in enumerate(int_points[:-1]):
            # Check to see if poll results are null for each sub_time in this window
            all_null = True
            for j in range(int_points[i],int_points[i+1]):
                if not pd.isnull(df.iloc[j,col_i]):
                    all_null = False
                    break
            # if poll results in the window create a search entry for this candidate
            if all_null == False:
                search_param = {}
                search_param['subject'] = subjects[subject]
                search_param['search_times'] = times[df.index[int_points[i]].replace('-','')+'000000']
                search_param['sub_dates'] = sub_times[df.index[int_points[i]].replace('-','')+'000000']
                search_params.append(search_param)
    return search_params
        

def create_poll_intervals(df = None):
    
    # Set the first date to the first date in the index - 7 days + 1 minute
    start_time = datetime.strptime(df.index[0],'%Y-%m-%d')-timedelta(days=7)+timedelta(minutes=1)
    start_time = start_time.strftime('%Y%m%d%H%M%S')

    # Create a dictionary that contains the poll periods within the dataframe with keys equal to last date
    times = {df.index[j+1]: (df.index[j].replace('-','')+'000100', 
             df.index[j+1].replace('-','')+'235900') for j in range(df.shape[0]-1)}
    times = {df.index[0] : (start_time,df.index[0].replace('-','')+'235900'), **times}
    return times

def interval_key(time = '', times = {}):
    # Search for the time in the dictionary of times
    for interval in times.keys():
        if int(time) >= int(times[interval][0]) and int(time)<=int(times[interval][1]):
            return interval
    return "not_found"
 
def extract_themes(in_text=''):
    return re.findall(r'[\w\d]*_[\w\d]*',in_text)

# %% [markdown]
# # Collect metrics data

# %% [markdown]
# ## Query BigQuery for press coverage and save to BigQuery table

# %% [markdown]
# ### Run one-time GDELT GKG query to get press coverage

# %%
# Set the search table
search_table = "`gdelt-bq.gdeltv2.gkg`"
dataset_id = 'rep_primary_press_coverage_2016'
table_id = 't1'

# Identify the search subjects
subjects = ['Donald Trump', 'John Kasich', 'Ted Cruz', 'Marco Rubio', 'Ben Carson', 'Jeb Bush', 
            'Chris Christie', 'Carly Fiorina', 'Rick Santorum', 'Rand Paul', 'Mike Huckabee']

# Set the start and end times
search_times = ('20150503000000','20160503000000')

# GDELT fields to retrieve
fields=['GKGRECORDID','Date','Allnames','Persons','V2Tone','V2Themes']

# Query ran flag
gdelt_query_ran = True

if gdelt_query_ran == False:
    # Instantiate the object to search the GDELT database
    press = PressInventory(search_table=search_table, dataset_id=dataset_id, table_id=table_id,
                           subjects=subjects, search_times=search_times,fields=fields, limit=None)
    # run the query
    press.collect_coverage()

# %% [markdown]
# ### Get the size of the table

# %%
table_id = "`campfireanalysis.rep_primary_press_coverage_2016.t1`"

# Instantiate the object
client = bigquery.Client()

sql = ( "SELECT table_id, row_count, size_bytes FROM `campfireanalysis.rep_primary_press_coverage_2016.__TABLES__`")

# Run the query
query_job = client.query(sql, location="US")

for row in query_job:
    print(row)

# https://stackoverflow.com/questions/54620402/get-number-of-rows-in-a-bigquery-table-streaming-buffer
# Out:
# Row(('t1', 44478183, 115723315941), {'table_id': 0, 'row_count': 1, 'size_bytes': 2})

# %% [markdown]
# ## Load in the 2016 poll data

# %%
# Get the pure poll data for 2016
df_polls_2016 = pd.read_csv('../data/pure_poll_data_2016.csv')
df_polls_2016.set_index('end_time', inplace = True)
df_polls_2016.head(5)
# Out:
#             Bush  Carson  Christie  Cruz  Fiorina  Huckabee  Kasich   Paul  \
# end_time
# 2015-02-15  0.12   0.090      0.07  0.03     0.01     0.170    0.02  0.110
# 2015-02-23  0.16   0.060      0.07  0.05     0.00     0.100    0.01  0.100
# 2015-03-02  0.16   0.070      0.08  0.06      NaN     0.080    0.01  0.060
# 2015-03-15  0.16   0.090      0.07  0.04     0.00     0.100    0.02  0.120
#  '2016-03-31': ('20160330000100', '20160331235900'),
#  '2016-04-01': ('20160331000100', '20160401235900'),
#  '2016-04-02': ('20160401000100', '20160402235900'),
#  '2016-04-03': ('20160402000100', '20160403235900'),
#  '2016-04-04': ('20160403000100', '20160404235900'),
#  '2016-04-05': ('20160404000100', '20160405235900'),
#  '2016-04-06': ('20160405000100', '20160406235900'),
#  '2016-04-07': ('20160406000100', '20160407235900'),
#  '2016-04-08': ('20160407000100', '20160408235900'),
#  '2016-04-09': ('20160408000100', '20160409235900'),
#  '2016-04-10': ('20160409000100', '20160410235900'),
#  '2016-04-11': ('20160410000100', '20160411235900'),
#  '2016-04-12': ('20160411000100', '20160412235900'),
#  '2016-04-13': ('20160412000100', '20160413235900'),
#  '2016-04-14': ('20160413000100', '20160414235900'),
#  '2016-04-15': ('20160414000100', '20160415235900'),
#  '2016-04-16': ('20160415000100', '20160416235900'),
#  '2016-04-17': ('20160416000100', '20160417235900'),
#  '2016-04-18': ('20160417000100', '20160418235900'),
#  '2016-04-19': ('20160418000100', '20160419235900'),
#  '2016-04-20': ('20160419000100', '20160420235900'),
#  '2016-04-21': ('20160420000100', '20160421235900'),
#  '2016-04-22': ('20160421000100', '20160422235900'),
#  '2016-04-23': ('20160422000100', '20160423235900'),
#  '2016-04-24': ('20160423000100', '20160424235900'),
#  '2016-04-25': ('20160424000100', '20160425235900'),
#  '2016-04-26': ('20160425000100', '20160426235900'),
#  '2016-04-27': ('20160426000100', '20160427235900'),
#  '2016-04-28': ('20160427000100', '20160428235900'),
#  '2016-04-29': ('20160428000100', '20160429235900'),
#  '2016-04-30': ('20160429000100', '20160430235900'),
#  '2016-05-01': ('20160430000100', '20160501235900'),
#  '2016-05-02': ('20160501000100', '20160502235900'),
#  '2016-05-03': ('20160502000100', '20160503235900')}

# %% [markdown]
# ### Create the search parameters

# %%
# Create a list of search parameters which
#  sets the subject of each search to one of the candidates
#  determines search times by breaking the full polling window into n intervals
#  if the candidate has no poll data for every date in the search window, no entry is created
subject_mapping  = {'Trump':'Donald Trump', 'Kasich': 'John Kasich', 'Cruz':'Ted Cruz', 
                    'Rubio':'Marco Rubio', 'Carson':'Ben Carson', 'Bush':'Jeb Bush', 
                    'Christie':'Chris Christie', 'Fiorina':'Carly Fiorina', 'Santorum':'Rick Santorum', 
                    'Paul':'Rand Paul', 'Huckabee':'Mike Huckabee'}
intervals = 16

search_params = create_search_parameters(df = df_polls_2016, subjects = subject_mapping, intervals = intervals)

# %%
# Examine the output
print(len(search_params[0]['sub_dates']))
search_params[0]
# Out:
# 1
# {'subject': 'Donald Trump',
#  'search_times': ('20150208000100', '20150215235900'),
#  'sub_dates': [('2015-02-08', '2015-02-15')]}

# %% [markdown]
# ### Test the method for retrieving data

# %%
# Look for press coverage according to the search criteria and return
#  a list of dictionaries with press metrics for each time window specified in
#  the time_intervals parameters; To do this the method calls the BigQuery API to collect 
#  data matching the search criteria from the search_table; The data fields collected for each 
#  interval are delineated in the fields column which must contain at least 'V2Tone' and 'V2Themes' 
#  since these are used to determine metrics;  Once the data for the search window are collected
#  the GKGPersonPressMetrics method collects press metrics for each interval in the 
#  time_intervals parameter falling within the search window;  A list of dictionaries is 
#  returned one for each interval with the subject, the metrics, the date index;  This list 
#  of dictionaries can be converted to a DataFrame for easy viewing and further manipulation

# Attributes of the data retrieval
search_table = "`campfireanalysis.rep_primary_press_coverage_2016.t1`"
fields = ['Date','V2Tone', 'V2Themes']
limit = None
data_path = '../data'
 
person_metric = GKGPersonPressMetrics(search_table=search_table, 
                                      search_parameters = search_params[0], fields = fields, limit=limit,
                                      time_intervals = poll_intervals)
person_metric.build_sql()

test_d = person_metric.collect_metrics()

# %%
test_d
# Out:
# {'2015-02-15': {'art_count': 0,
#   'tone_avg': nan,
#   'pos_score_avg': nan,
#   'neg_score_avg': nan,
#   'polarity_avg': nan,
#   'act_ref_den_avg': nan,
#   'self_ref_den_avg': nan,
#   'word_count': 0,
#   'themes': [],
#   'subject': 'Donald Trump'}}

# %%
df_test = pd.DataFrame(test_d).T
df_test.head()
# Out:
#            act_ref_den_avg art_count neg_score_avg polarity_avg pos_score_avg  \
# 2015-02-15             NaN         0           NaN          NaN           NaN
#
#            self_ref_den_avg       subject themes tone_avg word_count
# 2015-02-15              NaN  Donald Trump     []      NaN          0

# %%
print(len(df_test.loc['2015-03-02','themes']))
# Out:
# 1034

# %% [markdown]
# # Gather press data

# %% [markdown]
# ## Input parameters

# %%
# The DataFrame with polling data
df_polls = df_polls_2016

# The candidates to be searched
subject_mapping  = {'Trump':'Donald Trump', 'Kasich': 'John Kasich', 'Cruz':'Ted Cruz', 
                    'Rubio':'Marco Rubio', 'Carson':'Ben Carson', 'Bush':'Jeb Bush', 
                    'Christie':'Chris Christie', 'Fiorina':'Carly Fiorina', 'Santorum':'Rick Santorum', 
                    'Paul':'Rand Paul', 'Huckabee':'Mike Huckabee'}

# The number of intervals used to create search windows
intervals = 16

# Attributes of the data retrieval
search_table = "`campfireanalysis.rep_primary_press_coverage_2016.t1`"
fields = ['Date','V2Tone', 'V2Themes']
limit = None
data_path = '../data/press'

# %% [markdown]
# ## Run the search function

# %%
# Create a dataframe of press coverage
df_press_2016 = build_coverage_dataframe(df_polls = df_polls, subject_mapping = subject_mapping, 
                                         intervals = intervals, search_table = search_table, 
                                         fields = fields, search_limit = limit, data_path = data_path)
# Out:
# {'subject': 'Donald Trump', 'search_times': ('20150208000100', '20150215235900'), 'sub_dates': ('2015-02-08', '2015-02-15')}
# 2
# {'subject': 'Donald Trump', 'search_times': ('20150215000100', '20150409235900'), 'sub_dates': [('2015-02-15', '2015-02-23'), ('2015-02-23', '2015-03-02'), ('2015-03-02', '2015-03-15'), ('2015-03-15', '2015-03-19'), ('2015-03-19', '2015-03-20'), ('2015-03-20', '2015-03-21'), ('2015-03-21', '2015-03-22'), ('2015-03-22', '2015-03-23'), ('2015-03-23', '2015-03-24'), ('2015-03-24', '2015-03-25'), ('2015-03-25', '2015-03-26'), ('2015-03-26', '2015-03-27'), ('2015-03-27', '2015-03-28'), ('2015-03-28', '2015-03-29'), ('2015-03-29', '2015-03-30'), ('2015-03-30', '2015-03-31'), ('2015-03-31', '2015-04-01'), ('2015-04-01', '2015-04-02'), ('2015-04-02', '2015-04-03'), ('2015-04-03', '2015-04-04'), ('2015-04-04', '2015-04-05'), ('2015-04-05', '2015-04-06'), ('2015-04-06', '2015-04-07'), ('2015-04-07', '2015-04-08'), ('2015-04-08', '2015-04-09')]}
# 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-e8bd11292ab1> in <module>()
#       2 df_press_2016 = build_coverage_dataframe(df_polls = df_polls, subject_mapping = subject_mapping,
#       3                                          intervals = intervals, search_table = search_table,
# ----> 4                                          fields = fields, search_limit = limit, data_path = data_path)
#
# <ipython-input-178-bf8471edd9c0> in build_coverage_dataframe(df_polls, subject_mapping, intervals, search_table, fields, search_limit, data_path)
#      50
#      51     # Return a single DataFrame
# ---> 52     return pd.concat(df_collection, axis = 0)
#      53
#      54
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
#     264         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df_press_2016
# Out:
#                  subject art_count word_count  tone_avg pos_score_avg  \
# 0           Donald Trump         0          0       NaN           NaN
# 2015-02-23  Donald Trump         1        877   1.73536       4.12148
# 2015-03-02  Donald Trump         1        390  -3.42466       2.51142
# 2015-03-15  Donald Trump         2       1150 -0.776682       1.92184
# 2015-03-19  Donald Trump         0          0       NaN           NaN
# 2015-03-20  Donald Trump         0          0       NaN           NaN
# 2015-03-21  Donald Trump         0          0       NaN           NaN
# 2015-03-22  Donald Trump         0          0       NaN           NaN
# 2015-03-23  Donald Trump         0          0       NaN           NaN
# 2015-03-24  Donald Trump         0          0       NaN           NaN
# 2015-03-25  Donald Trump         0          0       NaN           NaN
# 2015-03-26  Donald Trump         0          0       NaN           NaN
# 2015-03-27  Donald Trump         0          0       NaN           NaN
# 2015-03-28  Donald Trump         0          0       NaN           NaN
# 2015-03-29  Donald Trump         0          0       NaN           NaN
# 2015-03-30  Donald Trump         0          0       NaN           NaN
# 2015-03-31  Donald Trump         0          0       NaN           NaN
# 2015-04-01  Donald Trump         0          0       NaN           NaN
# 2015-04-02  Donald Trump         0          0       NaN           NaN
# 2015-04-03  Donald Trump         0          0       NaN           NaN
# 2015-04-04  Donald Trump         0          0       NaN           NaN
# 2015-04-05  Donald Trump         0          0       NaN           NaN
# 2015-04-06  Donald Trump         0          0       NaN           NaN
# 2015-04-07  Donald Trump         0          0       NaN           NaN
# 2015-04-08  Donald Trump         0          0       NaN           NaN
# 2015-04-09  Donald Trump         0          0       NaN           NaN
#
#            neg_score_avg polarity_avg act_ref_den_avg self_ref_den_avg  \
# 0                    NaN          NaN             NaN              NaN
# 2015-02-23       2.38612      6.50759         24.9458           3.2538
# 2015-03-02       5.93607      8.44749         20.7763         0.456621
# 2015-03-15       2.69852      4.62037         22.0779          1.21281
# 2015-03-19           NaN          NaN             NaN              NaN
# 2015-03-20           NaN          NaN             NaN              NaN
# 2015-03-21           NaN          NaN             NaN              NaN
# 2015-03-22           NaN          NaN             NaN              NaN
# 2015-03-23           NaN          NaN             NaN              NaN
# 2015-03-24           NaN          NaN             NaN              NaN
# 2015-03-25           NaN          NaN             NaN              NaN
# 2015-03-26           NaN          NaN             NaN              NaN
# 2015-03-27           NaN          NaN             NaN              NaN
# 2015-03-28           NaN          NaN             NaN              NaN
# 2015-03-29           NaN          NaN             NaN              NaN
# 2015-03-30           NaN          NaN             NaN              NaN
# 2015-03-31           NaN          NaN             NaN              NaN
# 2015-04-01           NaN          NaN             NaN              NaN
# 2015-04-02           NaN          NaN             NaN              NaN
# 2015-04-03           NaN          NaN             NaN              NaN
# 2015-04-04           NaN          NaN             NaN              NaN
# 2015-04-05           NaN          NaN             NaN              NaN
# 2015-04-06           NaN          NaN             NaN              NaN
# 2015-04-07           NaN          NaN             NaN              NaN
# 2015-04-08           NaN          NaN             NaN              NaN
# 2015-04-09           NaN          NaN             NaN              NaN
#
#                                                        themes
# 0                                                          []
# 2015-02-23  [TAX_FNCACT, TAX_FNCACT, MEDIA_SOCIAL, TAX_ETH...
# 2015-03-02  [TAX_FNCACT_CANDIDATES, TAX_FNCACT_CANDIDATES,...
# 2015-03-15  [MANMADE_DISASTER_IMPLIED, WB_696_PUBLIC_SECTO...
# 2015-03-19                                                 []
# 2015-03-20                                                 []
# 2015-03-21                                                 []
# 2015-03-22                                                 []
# 2015-03-23                                                 []
# 2015-03-24                                                 []
# 2015-03-25                                                 []
# 2015-03-26                                                 []
# 2015-03-27                                                 []
# 2015-03-28                                                 []
# 2015-03-29                                                 []
# 2015-03-30                                                 []
# 2015-03-31                                                 []
# 2015-04-01                                                 []
# 2015-04-02                                                 []
# 2015-04-03                                                 []
# 2015-04-04                                                 []
# 2015-04-05                                                 []
# 2015-04-06                                                 []
# 2015-04-07                                                 []
# 2015-04-08                                                 []
# 2015-04-09                                                 []

# %% [markdown]
# ### remove - Establish search criteria

# %%
# Define a list of candidates to search media coverage
candidates = ['Donald Trump', 'John Kasich', 'Ted Cruz', 'Marco Rubio', 'Ben Carson', 
              'Jeb Bush', 'Chris Christie', 'Carly Fiorina', 'Rick Santorum', 'Rand Paul', 'Mike Huckabee']
# Start and ending times for the press coverage search corresponding to dates in the poll DataFrame
search_dates  = create_search_dates(df = df_polls_2016)
# GDELT fields to retrieve
fields=['V2Tone']
# Maximum number of articles to return
limit = 2500
dfs_of_metrics = []

# %% [markdown]
# ### remove - Search press coverage for each candidate

# %%
# Grab coverage metrics for each candidate for each day in the interval
#  append the out put to a list of DataFrames
for candidate in candidates:
    df1  = survey_coverage_by_subject_by_day(subject = candidate, start_time = start_time, end_time = end_time,
                                               fields = fields, limit = limit)
    dfs_of_metrics.append(df1)
# Out:
# Retrieving coverage metrics on Donald Trump for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Donald Trump for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Donald Trump for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Donald Trump for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Donald Trump for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Donald Trump for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Donald Trump for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Donald Trump for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on John Kasich for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on John Kasich for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on John Kasich for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on John Kasich for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on John Kasich for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on John Kasich for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on John Kasich for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on John Kasich for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Ted Cruz for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Ted Cruz for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Ted Cruz for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Ted Cruz for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Ted Cruz for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Ted Cruz for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Ted Cruz for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Ted Cruz for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Marco Rubio for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Marco Rubio for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Marco Rubio for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Marco Rubio for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Marco Rubio for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Marco Rubio for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Marco Rubio for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Marco Rubio for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Ben Carson for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Ben Carson for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Ben Carson for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Ben Carson for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Ben Carson for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Ben Carson for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Ben Carson for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Ben Carson for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Jeb Bush for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Jeb Bush for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Jeb Bush for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Jeb Bush for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Jeb Bush for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Jeb Bush for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Jeb Bush for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Jeb Bush for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Chris Christie for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Chris Christie for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Chris Christie for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Chris Christie for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Chris Christie for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Chris Christie for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Chris Christie for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Chris Christie for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Carly Fiorina for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Rick Santorum for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Rick Santorum for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Rick Santorum for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Rick Santorum for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Rick Santorum for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Rick Santorum for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Rick Santorum for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Rick Santorum for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Rand Paul for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Rand Paul for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Rand Paul for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Rand Paul for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Rand Paul for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Rand Paul for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Rand Paul for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Rand Paul for interval 20150227000000 to 20150228000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150220000000 to 20150221000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150221000000 to 20150222000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150222000000 to 20150223000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150223000000 to 20150224000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150224000000 to 20150225000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150225000000 to 20150226000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150226000000 to 20150227000000
# Retrieving coverage metrics on Mike Huckabee for interval 20150227000000 to 20150228000000

# %% [markdown]
# # Store in a DataFrame

# %% [markdown]
# ## Concatenate DataFrames

# %%
df_press = pd.concat(dfs_of_metrics, axis = 0, ignore_index = True)

# %%
df_press.shape
# Out:
# (88, 11)

# %%
df_press
# Out:
#           subject start_time   end_time  press_count  word_count  tone_avg  \
# 0    Donald Trump 2015-02-20 2015-02-21            1         877  1.735358
# 1    Donald Trump 2015-02-21 2015-02-22            0           0       NaN
# 2    Donald Trump 2015-02-22 2015-02-23            0           0       NaN
# 3    Donald Trump 2015-02-23 2015-02-24            0           0       NaN
# 4    Donald Trump 2015-02-24 2015-02-25            0           0       NaN
# 5    Donald Trump 2015-02-25 2015-02-26            0           0       NaN
# 6    Donald Trump 2015-02-26 2015-02-27            0           0       NaN
# 7    Donald Trump 2015-02-27 2015-02-28            1         390 -3.424658
# 8     John Kasich 2015-02-20 2015-02-21          283      215576  0.114556
# 9     John Kasich 2015-02-21 2015-02-22          103       71142 -1.370661
# 10    John Kasich 2015-02-22 2015-02-23          133       84655 -1.071046
# 11    John Kasich 2015-02-23 2015-02-24          162      124233 -0.615865
# 12    John Kasich 2015-02-24 2015-02-25          154       78202  0.731193
# 13    John Kasich 2015-02-25 2015-02-26          510      479576 -1.079491
# 14    John Kasich 2015-02-26 2015-02-27          131       82632 -1.516021
# 15    John Kasich 2015-02-27 2015-02-28           93       74251 -0.948538
# 16       Ted Cruz 2015-02-20 2015-02-21          314      228182 -1.061117
# 17       Ted Cruz 2015-02-21 2015-02-22          103       83873 -1.420687
# 18       Ted Cruz 2015-02-22 2015-02-23           98       79421 -0.378870
# 19       Ted Cruz 2015-02-23 2015-02-24          227      196835 -1.017490
# 20       Ted Cruz 2015-02-24 2015-02-25          188      148654 -1.711783
# 21       Ted Cruz 2015-02-25 2015-02-26          659      538861 -1.963297
# 22       Ted Cruz 2015-02-26 2015-02-27          833      603494 -1.077592
# 23       Ted Cruz 2015-02-27 2015-02-28          656      525839 -1.296245
# 24    Marco Rubio 2015-02-20 2015-02-21          573      441549  0.273729
# 25    Marco Rubio 2015-02-21 2015-02-22          272      192404 -0.009843
# 26    Marco Rubio 2015-02-22 2015-02-23           96       85603 -0.821610
# 27    Marco Rubio 2015-02-23 2015-02-24          260      275914 -1.007138
# 28    Marco Rubio 2015-02-24 2015-02-25          311      183538 -0.724763
# 29    Marco Rubio 2015-02-25 2015-02-26          251      217864 -0.901412
# ..            ...        ...        ...          ...         ...       ...
# 58  Carly Fiorina 2015-02-22 2015-02-23            9       16780 -0.603811
# 18       2.898096       3.276966      6.175062        21.524739
# 19       2.301405       3.318894      5.620299        22.206796
# 20       2.377462       4.089245      6.466707        21.969296
# 21       2.027878       3.991175      6.019053        23.466077
# 22       2.697704       3.775296      6.473000        22.480874
# 23       2.966607       4.262852      7.229460        22.044393
# 24       2.645635       2.371906      5.017540        21.677451
# 25       2.840655       2.850499      5.691154        21.723361
# 26       2.609481       3.431091      6.040572        22.546728
# 27       2.568505       3.575643      6.144147        22.435988
# 28       2.232440       2.957203      5.189643        21.044786
# 29       2.940769       3.842181      6.782950        21.339918
# ..            ...            ...           ...              ...
# 58       2.430807       3.034618      5.465425        19.094457
# 59       2.495584       3.103138      5.598721        20.700033
# 60       2.794237       2.741313      5.535550        21.735240
# 61       2.731768       3.007464      5.739232        20.239409
# 62       2.842752       3.053090      5.895842        21.513761
# 63       3.245488       4.013837      7.259325        21.354478
# 64       2.903002       3.136633      6.039634        22.961117
# 65       2.648013       2.960924      5.608937        21.409535
# 66       2.685814       3.545078      6.230892        21.598453
# 67       2.563033       2.693846      5.256879        21.236653
# 68       2.571314       3.040940      5.612254        21.008425
# 69       2.726087       2.703281      5.429368        20.808704
# 70       3.445640       2.182878      5.628519        21.488807
# 71       2.808447       4.039103      6.847550        21.367541
# 72            NaN            NaN           NaN              NaN
# 73            NaN            NaN           NaN              NaN
# 74            NaN            NaN           NaN              NaN
# 75            NaN            NaN           NaN              NaN
# 76            NaN            NaN           NaN              NaN
# 77            NaN            NaN           NaN              NaN
# 78            NaN            NaN           NaN              NaN
# 79       2.179837       3.269755      5.449591        22.343324
# 80       2.580606       3.650004      6.230610        21.265435
# 81       3.171253       2.246241      5.417494        21.073519
# 82       2.845606       3.724433      6.570039        22.127830
# 83       2.644426       3.831102      6.475527        23.260817
# 84       2.652118       3.678031      6.330149        21.446463
# 85       2.751281       2.825361      5.576642        20.622773
# 86       3.355576       2.377780      5.733355        21.514656
# 87       3.028382       2.607499      5.635882        21.381096
#
#     self_ref_den_avg
# 0           3.253796
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7           0.456621
# 8           0.811196
# 9           0.690252
# 10          0.918156
# 11          0.816513
# 12          0.553149
# 13          1.003572
# 14          0.885240
# 15          0.824511
# 16          0.921171
# 17          1.022015
# 18          0.833090
# 19          0.564826
# 20          0.825058
# 21          0.525313
# 22          0.740611
# 23          1.129023
# 24          0.812255
# 25          0.862731
# 26          0.902432
# 27          0.851297
# 28          1.235201
# 29          0.453810
# ..               ...
# 58          1.644184
# 59          0.645144
# 60          0.524559
# 61          0.719618
# 62          0.763073
# 63          0.951031
# 64          1.041727
# 65          0.628587
# 66          1.151812
# 67          0.877513
# 68          0.597170
# 69          0.300989
# 70          0.672615
# 71          1.103145
# 72               NaN
# 73               NaN
# 74               NaN
# 75               NaN
# 76               NaN
# 77               NaN
# 78               NaN
# 79          1.362398
# 80          0.659335
# 81          0.771459
# 82          0.852347
# 83          0.895611
# 84          0.809745
# 85          0.491374
# 86          0.772665
# 87          0.911710
#
# [88 rows x 11 columns]
